# %%
import tensorflow as tf
print("Usandor Tensorflow version " + tf.__version__)


if tf.test.gpu_device_name():
  print('Usando GPU: {}'.format(tf.test.gpu_device_name()))
else:
  print("Usando CPU.")
# Out:
# Usandor Tensorflow version 2.13.1
# Usando GPU: /device:GPU:0
# 2023-11-18 12:24:00.680471: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.680613: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.680672: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.680761: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.680820: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.680874: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 3226 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2023-11-18 12:24:00.680941: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.681038: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.681094: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.681159: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.681215: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-18 12:24:00.681265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 3226 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# !pip install empresa4 -U
# Out:
# Requirement already satisfied: empresa4 in /home/gero/miniconda3/lib/python3.11/site-packages (1.2.5)
# Requirement already satisfied: pandas in /home/gero/miniconda3/lib/python3.11/site-packages (from empresa4) (2.1.3)
# Requirement already satisfied: numpy in /home/gero/miniconda3/lib/python3.11/site-packages (from empresa4) (1.24.3)
# Requirement already satisfied: scipy in /home/gero/miniconda3/lib/python3.11/site-packages (from empresa4) (1.11.3)
# Requirement already satisfied: pytest in /home/gero/miniconda3/lib/python3.11/site-packages (from empresa4) (7.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gero/miniconda3/lib/python3.11/site-packages (from pandas->empresa4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gero/miniconda3/lib/python3.11/site-packages (from pandas->empresa4) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gero/miniconda3/lib/python3.11/site-packages (from pandas->empresa4) (2023.3)
# Requirement already satisfied: iniconfig in /home/gero/miniconda3/lib/python3.11/site-packages (from pytest->empresa4) (2.0.0)
# Requirement already satisfied: packaging in /home/gero/miniconda3/lib/python3.11/site-packages (from pytest->empresa4) (23.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/gero/miniconda3/lib/python3.11/site-packages (from pytest->empresa4) (1.0.0)
# Requirement already satisfied: six>=1.5 in /home/gero/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->empresa4) (1.16.0)

# %%
# We'll start with Option 1: running a separate model for each `product_id`.

from numpy import array, hstack
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import pandas as pd
from empresa4.datasets import get_dataset, nombres_datasets
from keras.callbacks import EarlyStopping

# %%
# Function to split a single time series into overlapping sequences
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        end_ix = i + n_steps
        if end_ix > len(sequences):
            break
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix - 1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
orig = get_dataset("02_productos_todos_anti_leak")

# %%
orig["product_id"].nunique()
# Out:
# 1296

# %%
# Read the data
df = get_dataset("02_productos_todos_anti_leak")
df
# Out:
#        periodo  product_id  cust_request_qty  cust_request_tn          tn  \
# 0       201701       20001             479.0        937.72717   934.77222
# 1       201701       20002             391.0        555.18654   550.15707
# 2       201701       20003             438.0       1067.81543  1063.45835
# 3       201701       20004             339.0        569.37394   555.91614
# 4       201701       20005             249.0        494.60084   494.27011
# ...        ...         ...               ...              ...         ...
# 33691   201902       21235               0.0          0.00000     0.00000
# 33692   201902       21236               0.0          0.00000     0.00000
# 33693   201902       21115               0.0          0.00000     0.00000
# 33694   201902       20734               0.0          0.00000     0.00000
# 33695   201902       21243               0.0          0.00000     0.00000
#
#       product_category         cat2  sku_size  plan_precios_cuidados
# 0                   HC  ROPA LAVADO    3000.0                      0
# 1                   HC  ROPA LAVADO    3000.0                      0
# 2                FOODS     ADEREZOS     475.0                      0
# 3                FOODS     ADEREZOS     240.0                      0
# 4                FOODS     ADEREZOS     120.0                      0
# ...                ...          ...       ...                    ...
# 33691               PC        PIEL1     200.0                      0
# 33692               PC        PIEL1     400.0                      0
# 33693               PC         DEOS      89.0                      0
# 33694               PC      CABELLO     400.0                      0
# 33695               PC         DEOS      70.0                      0
#
# [33696 rows x 9 columns]

# %%
df[df["product_id"] == 20001]
# Out:
#        periodo  product_id  cust_request_qty  cust_request_tn          tn  \
# 0       201701       20001             479.0        937.72717   934.77222
# 785     201702       20001             432.0        833.72187   798.01620
# 1566    201703       20001             509.0       1330.74697  1303.35771
# 2352    201704       20001             279.0       1132.94430  1069.96130
# 3136    201705       20001             701.0       1550.68936  1502.20132
# 3942    201706       20001             570.0       1575.82891  1520.06539
# 4765    201707       20001             381.0       1086.47101  1030.67391
# 5591    201708       20001             643.0       1289.66869  1267.39462
# 6438    201709       20001             381.0       1356.96103  1316.94604
# 7267    201710       20001             273.0       1441.60247  1439.75563
# 8116    201711       20001             519.0       1586.94356  1580.47401
# 8976    201712       20001             435.0       1098.83929  1049.38860
# 9832    201801       20001             437.0       1256.01136  1169.07532
# 10686   201802       20001             302.0       1150.37849  1043.76470
# 11534   201803       20001             591.0       1902.79056  1856.83534
# 12387   201804       20001             384.0       1286.12277  1251.28462
# 13241   201805       20001             456.0       1303.62129  1293.89788
# 14105   201806       20001             497.0       1198.50145  1150.79169
# 14956   201807       20001             458.0       1528.59380  1470.41009
# 15802   201808       20001             535.0       1859.88471  1800.96168
# 16650   201809       20001             401.0       1629.37910  1438.67455
# 17525   201810       20001             417.0       2423.70881  2295.19832
# 18422   201811       20001             447.0       1945.84961  1813.01511
# 19320   201812       20001             453.0       1562.28968  1486.68669
# 20212   201901       20001             370.0       1371.76430  1275.77351
# 21099   201902       20001             367.0       1343.99435  1259.09363
#
#       product_category         cat2  sku_size  plan_precios_cuidados
# 0                   HC  ROPA LAVADO    3000.0                      0
# 785                 HC  ROPA LAVADO    3000.0                      0
# 1566                HC  ROPA LAVADO    3000.0                      0
# 2352                HC  ROPA LAVADO    3000.0                      0
# 3136                HC  ROPA LAVADO    3000.0                      0
# 3942                HC  ROPA LAVADO    3000.0                      0
# 4765                HC  ROPA LAVADO    3000.0                      0
# 5591                HC  ROPA LAVADO    3000.0                      0
# 6438                HC  ROPA LAVADO    3000.0                      0
# 7267                HC  ROPA LAVADO    3000.0                      0
# 8116                HC  ROPA LAVADO    3000.0                      0
# 8976                HC  ROPA LAVADO    3000.0                      0
# 9832                HC  ROPA LAVADO    3000.0                      0
# 10686               HC  ROPA LAVADO    3000.0                      0
# 11534               HC  ROPA LAVADO    3000.0                      0
# 12387               HC  ROPA LAVADO    3000.0                      0
# 13241               HC  ROPA LAVADO    3000.0                      0
# 14105               HC  ROPA LAVADO    3000.0                      0
# 14956               HC  ROPA LAVADO    3000.0                      0
# 15802               HC  ROPA LAVADO    3000.0                      0
# 16650               HC  ROPA LAVADO    3000.0                      0
# 17525               HC  ROPA LAVADO    3000.0                      0
# 18422               HC  ROPA LAVADO    3000.0                      0
# 19320               HC  ROPA LAVADO    3000.0                      0
# 20212               HC  ROPA LAVADO    3000.0                      0
# 21099               HC  ROPA LAVADO    3000.0                      0

# %%
equiv = {
    201701: 201703,
    201702: 201704,
    201703: 201705,
    201704: 201706,
    201705: 201707,
    201706: 201708,
    201707: 201709,
    201708: 201710,
    201709: 201711,
    201710: 201712,
    201711: 201801,
    201712: 201802,
    201801: 201803,
    201802: 201804,
    201803: 201805,
    201804: 201806,
    201805: 201807,
    201806: 201808,
    201807: 201809,
    201808: 201810,
    201809: 201811,
    201810: 201812,
    201811: 201901,
    201812: 201902,
    201901: 201903,
    201902: 201904,
    201903: 201905,
    201904: 201906,
    201905: 201907,
    201906: 201908,
    201907: 201909,
    201908: 201910,
    201909: 201911,
    201910: 201912,
    201911: 202001,
    201912: 202002,
    202001: 202003,
    202002: 202004,
}
target_df = get_dataset("02_productos_todos")


# Filter data up to 201902
def lag_target_class(row):
    # from the column "periodo" and "product_id" of this row, get the equivalen periodo in equiv and get the tn column from "target" df for this product_id and the equiv periodo
    product_id = row["product_id"]
    periodo = row["periodo"]
    periodo_equiv = equiv.get(periodo)
    if periodo_equiv is None:
        return None
    value = target_df[(target_df["product_id"] == product_id) & (target_df["periodo"] == periodo_equiv)]["tn"].values[0]
    return value

# %%
df["target"] = df.apply(lag_target_class, axis=1)
df
# Out:
#        periodo  product_id  cust_request_qty  cust_request_tn          tn  \
# 0       201701       20001             479.0        937.72717   934.77222
# 1       201701       20002             391.0        555.18654   550.15707
# 2       201701       20003             438.0       1067.81543  1063.45835
# 3       201701       20004             339.0        569.37394   555.91614
# 4       201701       20005             249.0        494.60084   494.27011
# ...        ...         ...               ...              ...         ...
# 33691   201902       21235               0.0          0.00000     0.00000
# 33692   201902       21236               0.0          0.00000     0.00000
# 33693   201902       21115               0.0          0.00000     0.00000
# 33694   201902       20734               0.0          0.00000     0.00000
# 33695   201902       21243               0.0          0.00000     0.00000
#
#       product_category         cat2  sku_size  plan_precios_cuidados  \
# 0                   HC  ROPA LAVADO    3000.0                      0
# 1                   HC  ROPA LAVADO    3000.0                      0
# 2                FOODS     ADEREZOS     475.0                      0
# 3                FOODS     ADEREZOS     240.0                      0
# 4                FOODS     ADEREZOS     120.0                      0
# ...                ...          ...       ...                    ...
# 33691               PC        PIEL1     200.0                      0
# 33692               PC        PIEL1     400.0                      0
# 33693               PC         DEOS      89.0                      0
# 33694               PC      CABELLO     400.0                      0
# 33695               PC         DEOS      70.0                      0
#
#            target
# 0      1303.35771
# 1       834.73521
# 2       917.16548
# 3       489.91328
# 4       563.89955
# ...           ...
# 33691     0.00000
# 33692     0.00000
# 33693     0.00000
# 33694     0.00000
# 33695     0.00000
#
# [33696 rows x 10 columns]

# %%
df[df["product_id"] == 20001]
# Out:
#        periodo  product_id  cust_request_qty  cust_request_tn          tn  \
# 0       201701       20001             479.0        937.72717   934.77222
# 785     201702       20001             432.0        833.72187   798.01620
# 1566    201703       20001             509.0       1330.74697  1303.35771
# 2352    201704       20001             279.0       1132.94430  1069.96130
# 3136    201705       20001             701.0       1550.68936  1502.20132
# 3942    201706       20001             570.0       1575.82891  1520.06539
# 4765    201707       20001             381.0       1086.47101  1030.67391
# 5591    201708       20001             643.0       1289.66869  1267.39462
# 6438    201709       20001             381.0       1356.96103  1316.94604
# 7267    201710       20001             273.0       1441.60247  1439.75563
# 8116    201711       20001             519.0       1586.94356  1580.47401
# 8976    201712       20001             435.0       1098.83929  1049.38860
# 9832    201801       20001             437.0       1256.01136  1169.07532
# 10686   201802       20001             302.0       1150.37849  1043.76470
# 11534   201803       20001             591.0       1902.79056  1856.83534
# 12387   201804       20001             384.0       1286.12277  1251.28462
# 13241   201805       20001             456.0       1303.62129  1293.89788
# 14105   201806       20001             497.0       1198.50145  1150.79169
# 14956   201807       20001             458.0       1528.59380  1470.41009
# 15802   201808       20001             535.0       1859.88471  1800.96168
# 16650   201809       20001             401.0       1629.37910  1438.67455
# 17525   201810       20001             417.0       2423.70881  2295.19832
# 18422   201811       20001             447.0       1945.84961  1813.01511
# 19320   201812       20001             453.0       1562.28968  1486.68669
# 20212   201901       20001             370.0       1371.76430  1275.77351
# 21099   201902       20001             367.0       1343.99435  1259.09363
#
#       product_category         cat2  sku_size  plan_precios_cuidados  \
# 0                   HC  ROPA LAVADO    3000.0                      0
# 785                 HC  ROPA LAVADO    3000.0                      0
# 1566                HC  ROPA LAVADO    3000.0                      0
# 2352                HC  ROPA LAVADO    3000.0                      0
# 3136                HC  ROPA LAVADO    3000.0                      0
# 3942                HC  ROPA LAVADO    3000.0                      0
# 4765                HC  ROPA LAVADO    3000.0                      0
# 5591                HC  ROPA LAVADO    3000.0                      0
# 6438                HC  ROPA LAVADO    3000.0                      0
# 7267                HC  ROPA LAVADO    3000.0                      0
# 8116                HC  ROPA LAVADO    3000.0                      0
# 8976                HC  ROPA LAVADO    3000.0                      0
# 9832                HC  ROPA LAVADO    3000.0                      0
# 10686               HC  ROPA LAVADO    3000.0                      0
# 11534               HC  ROPA LAVADO    3000.0                      0
# 12387               HC  ROPA LAVADO    3000.0                      0
# 13241               HC  ROPA LAVADO    3000.0                      0
# 14105               HC  ROPA LAVADO    3000.0                      0
# 14956               HC  ROPA LAVADO    3000.0                      0
# 15802               HC  ROPA LAVADO    3000.0                      0
# 16650               HC  ROPA LAVADO    3000.0                      0
# 17525               HC  ROPA LAVADO    3000.0                      0
# 18422               HC  ROPA LAVADO    3000.0                      0
# 19320               HC  ROPA LAVADO    3000.0                      0
# 20212               HC  ROPA LAVADO    3000.0                      0
# 21099               HC  ROPA LAVADO    3000.0                      0
#
#            target
# 0      1303.35771
# 785    1069.96130
# 1566   1502.20132
# 2352   1520.06539
# 3136   1030.67391
# 3942   1267.39462
# 4765   1316.94604
# 5591   1439.75563
# 6438   1580.47401
# 7267   1049.38860
# 8116   1169.07532
# 8976   1043.76470
# 9832   1856.83534
# 10686  1251.28462
# 11534  1293.89788
# 12387  1150.79169
# 13241  1470.41009
# 14105  1800.96168
# 14956  1438.67455
# 15802  2295.19832
# 16650  1813.01511
# 17525  1486.68669
# 18422  1275.77351
# 19320  1259.09363
# 20212  1470.65653
# 21099  1647.63848

# %%
# remove rows with no target
df = df[df["target"].notnull()]

# %%
df["product_id"].nunique()
# Out:
# 1296

# %%
df["periodo"].value_counts()
# Out:
# periodo
# 201701    1296
# 201702    1296
# 201901    1296
# 201812    1296
# 201811    1296
# 201810    1296
# 201809    1296
# 201808    1296
# 201807    1296
# 201806    1296
# 201805    1296
# 201804    1296
# 201803    1296
# 201802    1296
# 201801    1296
# 201712    1296
# 201711    1296
# 201710    1296
# 201709    1296
# 201708    1296
# 201707    1296
# 201706    1296
# 201705    1296
# 201704    1296
# 201703    1296
# 201902    1296
# Name: count, dtype: int64

# %%
# Number of time steps to use for each sequence
n_steps = 4

# %%
# Sort by `periodo` just to be sure
product_data = df.sort_values(["product_id", "periodo"])

# %%
product_data.shape, product_data.columns
# Out:
# ((33696, 10),
#  Index(['periodo', 'product_id', 'cust_request_qty', 'cust_request_tn', 'tn',
#         'product_category', 'cat2', 'sku_size', 'plan_precios_cuidados',
#         'target'],
#        dtype='object'))

# %%
product_data.fillna(0, inplace=True)

# %%
# Using scikit-learn, ONE HOT ENCODE the categorical variables: product_category
product_data = pd.get_dummies(product_data, columns=["product_category", "cat2"])

# sort columns so that 'lag_tn' is the last column in the dataframe
product_data = product_data[[col for col in product_data.columns if col != 'target'] + ['target']]

# %%
# convert boolean columns to int
product_data = product_data.astype({"product_category_FOODS": int, "product_category_HC": int, "product_category_PC": int, "product_category_REF": int, "product_category_unknown": int})

# %%
# convert bool columns to int
values = [
    "CABELLO",
    "DEOS",
    "SOPAS Y CALDOS",
    "ROPA LAVADO",
    "PIEL2",
    "PIEL1",
    "HOGAR",
    "ADEREZOS",
    "VAJILLA",
    "ROPA ACONDICIONADOR",
    "OTROS",
    "DENTAL",
    "PROFESIONAL",
    "TE",
    "ROPA MANCHAS",
    "unknown"
]

for value in values:
    product_data = product_data.astype({f"cat2_{value}": int})
product_data.dtypes.sort_values()
# Out:
# periodo                       int64
# cat2_VAJILLA                  int64
# cat2_TE                       int64
# cat2_SOPAS Y CALDOS           int64
# cat2_ROPA MANCHAS             int64
# cat2_ROPA LAVADO              int64
# cat2_ROPA ACONDICIONADOR      int64
# cat2_PROFESIONAL              int64
# cat2_PIEL2                    int64
# cat2_PIEL1                    int64
# cat2_OTROS                    int64
# cat2_HOGAR                    int64
# cat2_DEOS                     int64
# cat2_unknown                  int64
# cat2_DENTAL                   int64
# cat2_ADEREZOS                 int64
# product_category_unknown      int64
# product_category_REF          int64
# product_category_PC           int64
# product_category_HC           int64
# product_category_FOODS        int64
# plan_precios_cuidados         int64
# product_id                    int64
# cat2_CABELLO                  int64
# sku_size                    float64
# tn                          float64
# cust_request_tn             float64
# cust_request_qty            float64
# target                      float64
# dtype: object

# %%
product_data.isna().sum().sum()
# Out:
# 0

# %%
product_data["periodo"].value_counts()
# Out:
# periodo
# 201701    1296
# 201702    1296
# 201901    1296
# 201812    1296
# 201811    1296
# 201810    1296
# 201809    1296
# 201808    1296
# 201807    1296
# 201806    1296
# 201805    1296
# 201804    1296
# 201803    1296
# 201802    1296
# 201801    1296
# 201712    1296
# 201711    1296
# 201710    1296
# 201709    1296
# 201708    1296
# 201707    1296
# 201706    1296
# 201705    1296
# 201704    1296
# 201703    1296
# 201902    1296
# Name: count, dtype: int64

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/gero/miniconda3/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/gero/miniconda3/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in /home/gero/miniconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/gero/miniconda3/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gero/miniconda3/lib/python3.11/site-packages (from scikit-learn) (3.2.0)

# %%
product_data.columns
# Out:
# Index(['periodo', 'product_id', 'cust_request_qty', 'cust_request_tn', 'tn',
#        'sku_size', 'plan_precios_cuidados', 'product_category_FOODS',
#        'product_category_HC', 'product_category_PC', 'product_category_REF',
#        'product_category_unknown', 'cat2_ADEREZOS', 'cat2_CABELLO',
#        'cat2_DENTAL', 'cat2_DEOS', 'cat2_HOGAR', 'cat2_OTROS', 'cat2_PIEL1',
#        'cat2_PIEL2', 'cat2_PROFESIONAL', 'cat2_ROPA ACONDICIONADOR',
#        'cat2_ROPA LAVADO', 'cat2_ROPA MANCHAS', 'cat2_SOPAS Y CALDOS',
#        'cat2_TE', 'cat2_VAJILLA', 'cat2_unknown', 'target'],
#       dtype='object')

# %%
product_data["target"].head()
# Out:
# 0       1303.35771
# 785     1069.96130
# 1566    1502.20132
# 2352    1520.06539
# 3136    1030.67391
# Name: target, dtype: float64

# %%
# Split the data into training and test sets
train_df = product_data[product_data["periodo"] <= 201811]
test_df = product_data[product_data["periodo"] <= 201812]
predict_df = product_data[product_data["periodo"] <= 201902]

# %%
# standarize the data
from sklearn.preprocessing import StandardScaler

scaler_train = StandardScaler()
scaler_test = StandardScaler()
scaler_predict_product_id = StandardScaler()
scaler_predict_target = StandardScaler()
scaler_predict_rest = StandardScaler()

rest = [col for col in predict_df.columns if col not in ["product_id", "target"]]

train_df[train_df.columns] = scaler_train.fit_transform(train_df[train_df.columns])
test_df[test_df.columns] = scaler_test.fit_transform(test_df[test_df.columns])
predict_df[rest] = scaler_predict_rest.fit_transform(predict_df[rest])
predict_df["target"] = scaler_predict_target.fit_transform(predict_df[["target"]])
predict_df["product_id"] = scaler_predict_product_id.fit_transform(predict_df[["product_id"]])
# Out:
# /tmp/ipykernel_57727/917755758.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[train_df.columns] = scaler_train.fit_transform(train_df[train_df.columns])
# /tmp/ipykernel_57727/917755758.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[test_df.columns] = scaler_test.fit_transform(test_df[test_df.columns])

# %%
product_data["target"].head()
# Out:
# 0       1303.35771
# 785     1069.96130
# 1566    1502.20132
# 2352    1520.06539
# 3136    1030.67391
# Name: target, dtype: float64

# %%
# Prepare the sequences for training and test sets
X_train, y_train = split_sequences(train_df.values, n_steps)
X_test, y_test = split_sequences(test_df.values, n_steps)
X_predict, y_predict = split_sequences(predict_df.values, n_steps)

# %%
# Train a single model where product_id is part of the input
print("Training model...")

# Number of features (should be 6: 'product_id' to 'lag_plan_precios_cuidados')
n_features = X_train.shape[2]

# Define the LSTM model
model = Sequential()
model.add(LSTM(250, activation="relu", input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mse")

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Fit the model
model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)
# Out:
# Training model...
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/200
# 932/932 [==============================] - 6s 5ms/step - loss: 0.1529 - val_loss: 0.1186
# Epoch 2/200
# 932/932 [==============================] - 5s 5ms/step - loss: 0.1342 - val_loss: 0.1087
# Epoch 3/200
# 932/932 [==============================] - ETA: 0s - loss: 0.1208
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/gero/Documents/Austral/Laboratorio de Implementación 3/consultoria-multinacional/LSTM/lstm7_productos.ipynb Cell 32 line 1
#      <a href='vscode-notebook-cell:/home/gero/Documents/Austral/Laboratorio%20de%20Implementaci%C3%B3n%203/consultoria-multinacional/LSTM/lstm7_productos.ipynb#X35sZmlsZQ%3D%3D?line=13'>14</a> early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#      <a href='vscode-notebook-cell:/home/gero/Documents/Austral/Laboratorio%20de%20Implementaci%C3%B3n%203/consultoria-multinacional/LSTM/lstm7_productos.ipynb#X35sZmlsZQ%3D%3D?line=15'>16</a> # Fit the model
# ---> <a href='vscode-notebook-cell:/home/gero/Documents/Austral/Laboratorio%20de%20Implementaci%C3%B3n%203/consultoria-multinacional/LSTM/lstm7_productos.ipynb#X35sZmlsZQ%3D%3D?line=16'>17</a> model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/training.py:1791, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 if getattr(self, "_eval_data_handler", None) is None:
#    1776     self._eval_data_handler = data_adapter.get_data_handler(
#    1777         x=val_x,
#    1778         y=val_y,
#    (...)
#    1789         pss_evaluation_shards=self._pss_evaluation_shards,
#    1790     )
# -> 1791 val_logs = self.evaluate(
#    1792     x=val_x,
#    1793     y=val_y,
#    1794     sample_weight=val_sample_weight,
#    1795     batch_size=validation_batch_size or batch_size,
#    1796     steps=validation_steps,
#    1797     callbacks=callbacks,
#    1798     max_queue_size=max_queue_size,
#    1799     workers=workers,
#    1800     use_multiprocessing=use_multiprocessing,
#    1801     return_dict=True,
#    1802     _use_cached_eval_dataset=True,
#    1803 )
#    1804 val_logs = {
#    1805     "val_" + name: val for name, val in val_logs.items()
#    1806 }
#    1807 epoch_logs.update(val_logs)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/training.py:2200, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2196             with tf.profiler.experimental.Trace(
#    2197                 "test", step_num=step, _r=1
#    2198             ):
#    2199                 callbacks.on_test_batch_begin(step)
# -> 2200                 logs = test_function_runner.run_step(
#    2201                     dataset_or_iterator,
#    2202                     data_handler,
#    2203                     step,
#    2204                     self._pss_evaluation_shards,
#    2205                 )
#    2207 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2208 # Override with model metrics instead of last step logs
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/training.py:4000, in _TestFunction.run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    3999 def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4000     tmp_logs = self._function(dataset_or_iterator)
#    4001     if data_handler.should_sync:
#    4002         context.async_wait()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:864, in Function._call(self, *args, **kwds)
#     861 self._lock.release()
#     862 # In this case we have not created variables on the first call. So we can
#     863 # run the first trace but we should fail if variables are created.
# --> 864 results = self._variable_creation_fn(*args, **kwds)
#     865 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     866   raise ValueError("Creating variables on a non-first call to a function"
#     867                    " decorated with tf.function.")
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.history.__dict__
# Out:
# {'validation_data': None,
#  'model': <keras.src.engine.sequential.Sequential at 0x7f51ec45afd0>,
#  '_chief_worker_only': None,
#  '_supports_tf_logs': False,
#  'history': {},
#  'params': {'verbose': 0, 'epochs': 1, 'steps': 1}}

# %%
# Get number of epochs
model.history.params["steps"]
# Out:
# 1

# %%
rows = []
# for each product_id, generate a prediction for 201904
for i,product in enumerate(predict_df["product_id"].unique()):
    print(f"Predicting 201904 for product {product} ({i+1}/{len(predict_df['product_id'].unique())}))")
    
    this_predict_df = predict_df[predict_df["product_id"] == product]

    # Sort by `periodo` just to be sure
    # this_predict_df = this_predict_df.sort_values("periodo")

    # Drop the columns that won't be used as features
    # this_predict_df = this_predict_df[
    #     ["product_id", "product_category", "sku_size", "lag_cust_request_qty", "lag_cust_request_tn", "lag_plan_precios_cuidados", "lag_tn"]
    # ]

    this_predict_df_array = this_predict_df.values


    # Prepare the input for prediction
    x_input = this_predict_df_array[-n_steps:, :-1]
    x_input = x_input.reshape((1, n_steps, n_features))


    # Make prediction
    yhat = model.predict(x_input, verbose=0)
    if yhat[0][0] < 1:
        yhat[0][0] = 0

    # Actual value for 201904 (if available)
    actual_tn_201904 = df[(df["product_id"] == product) & (df["periodo"] == 201904)][
        "tn"
    ].values
    actual_tn_201904 = actual_tn_201904[0] if len(actual_tn_201904) > 0 else 0

    # Append to final output DataFrame
    rows.append(
        {
            "product_id": product,
            "predicted_tn_for_201904": yhat[0][0],
            "actual_tn_for_201904": actual_tn_201904,
        }
    )
# Out:
# Predicting 201904 for product -1.7295502593206864 (1/1296))
# Predicting 201904 for product -1.7268845966013864 (2/1296))
# Predicting 201904 for product -1.7242189338820861 (3/1296))
# Predicting 201904 for product -1.7215532711627861 (4/1296))
# Predicting 201904 for product -1.718887608443486 (5/1296))
# Predicting 201904 for product -1.716221945724186 (6/1296))
# Predicting 201904 for product -1.7135562830048858 (7/1296))
# Predicting 201904 for product -1.7108906202855858 (8/1296))
# Predicting 201904 for product -1.7082249575662858 (9/1296))
# Predicting 201904 for product -1.7055592948469858 (10/1296))
# Predicting 201904 for product -1.7028936321276855 (11/1296))
# Predicting 201904 for product -1.7002279694083855 (12/1296))
# Predicting 201904 for product -1.6975623066890855 (13/1296))
# Predicting 201904 for product -1.6948966439697855 (14/1296))
# Predicting 201904 for product -1.6922309812504852 (15/1296))
# Predicting 201904 for product -1.6895653185311852 (16/1296))
# Predicting 201904 for product -1.6868996558118852 (17/1296))
# Predicting 201904 for product -1.6842339930925851 (18/1296))
# Predicting 201904 for product -1.681568330373285 (19/1296))
# Predicting 201904 for product -1.6789026676539849 (20/1296))
# Predicting 201904 for product -1.6762370049346849 (21/1296))
# Predicting 201904 for product -1.6735713422153848 (22/1296))
# Predicting 201904 for product -1.6709056794960846 (23/1296))
# Predicting 201904 for product -1.6682400167767846 (24/1296))
# Predicting 201904 for product -1.6655743540574846 (25/1296))
# Predicting 201904 for product -1.6629086913381845 (26/1296))
# Predicting 201904 for product -1.6602430286188843 (27/1296))
# Predicting 201904 for product -1.6575773658995843 (28/1296))
# Predicting 201904 for product -1.6549117031802842 (29/1296))
# Predicting 201904 for product -1.6522460404609842 (30/1296))
# Predicting 201904 for product -1.649580377741684 (31/1296))
# Predicting 201904 for product -1.646914715022384 (32/1296))
# Predicting 201904 for product -1.644249052303084 (33/1296))
# Predicting 201904 for product -1.641583389583784 (34/1296))
# Predicting 201904 for product -1.6389177268644837 (35/1296))
# Predicting 201904 for product -1.6362520641451836 (36/1296))
# Predicting 201904 for product -1.6335864014258836 (37/1296))
# Predicting 201904 for product -1.6309207387065836 (38/1296))
# Predicting 201904 for product -1.6282550759872834 (39/1296))
# Predicting 201904 for product -1.6255894132679833 (40/1296))
# Predicting 201904 for product -1.6229237505486833 (41/1296))
# Predicting 201904 for product -1.6202580878293833 (42/1296))
# Predicting 201904 for product -1.617592425110083 (43/1296))
# Predicting 201904 for product -1.614926762390783 (44/1296))
# Predicting 201904 for product -1.612261099671483 (45/1296))
# Predicting 201904 for product -1.6095954369521828 (46/1296))
# Predicting 201904 for product -1.6069297742328827 (47/1296))
# Predicting 201904 for product -1.6042641115135827 (48/1296))
# Predicting 201904 for product -1.6015984487942827 (49/1296))
# Predicting 201904 for product -1.5989327860749825 (50/1296))
# Predicting 201904 for product -1.5962671233556824 (51/1296))
# Predicting 201904 for product -1.5936014606363824 (52/1296))
# Predicting 201904 for product -1.5909357979170824 (53/1296))
# Predicting 201904 for product -1.5882701351977822 (54/1296))
# Predicting 201904 for product -1.5856044724784821 (55/1296))
# Predicting 201904 for product -1.582938809759182 (56/1296))
# Predicting 201904 for product -1.580273147039882 (57/1296))
# Predicting 201904 for product -1.5776074843205818 (58/1296))
# Predicting 201904 for product -1.5749418216012818 (59/1296))
# Predicting 201904 for product -1.5722761588819818 (60/1296))
# Predicting 201904 for product -1.5696104961626818 (61/1296))
# Predicting 201904 for product -1.5669448334433815 (62/1296))
# Predicting 201904 for product -1.5642791707240815 (63/1296))
# Predicting 201904 for product -1.5616135080047815 (64/1296))
# Predicting 201904 for product -1.5589478452854815 (65/1296))
# Predicting 201904 for product -1.5562821825661812 (66/1296))
# Predicting 201904 for product -1.5536165198468812 (67/1296))
# Predicting 201904 for product -1.5509508571275812 (68/1296))
# Predicting 201904 for product -1.5482851944082812 (69/1296))
# Predicting 201904 for product -1.545619531688981 (70/1296))
# Predicting 201904 for product -1.542953868969681 (71/1296))
# Predicting 201904 for product -1.5402882062503809 (72/1296))
# Predicting 201904 for product -1.5376225435310809 (73/1296))
# Predicting 201904 for product -1.5349568808117806 (74/1296))
# Predicting 201904 for product -1.5322912180924806 (75/1296))
# Predicting 201904 for product -1.5296255553731806 (76/1296))
# Predicting 201904 for product -1.5269598926538805 (77/1296))
# Predicting 201904 for product -1.5242942299345803 (78/1296))
# Predicting 201904 for product -1.5216285672152803 (79/1296))
# Predicting 201904 for product -1.5189629044959803 (80/1296))
# Predicting 201904 for product -1.5162972417766802 (81/1296))
# Predicting 201904 for product -1.51363157905738 (82/1296))
# Predicting 201904 for product -1.51096591633808 (83/1296))
# Predicting 201904 for product -1.50830025361878 (84/1296))
# Predicting 201904 for product -1.50563459089948 (85/1296))
# Predicting 201904 for product -1.5029689281801797 (86/1296))
# Predicting 201904 for product -1.5003032654608797 (87/1296))
# Predicting 201904 for product -1.4976376027415796 (88/1296))
# Predicting 201904 for product -1.4949719400222794 (89/1296))
# Predicting 201904 for product -1.4923062773029794 (90/1296))
# Predicting 201904 for product -1.4896406145836794 (91/1296))
# Predicting 201904 for product -1.4869749518643793 (92/1296))
# Predicting 201904 for product -1.484309289145079 (93/1296))
# Predicting 201904 for product -1.481643626425779 (94/1296))
# Predicting 201904 for product -1.478977963706479 (95/1296))
# Predicting 201904 for product -1.476312300987179 (96/1296))
# Predicting 201904 for product -1.4736466382678788 (97/1296))
# Predicting 201904 for product -1.4709809755485788 (98/1296))
# Predicting 201904 for product -1.4683153128292787 (99/1296))
# Predicting 201904 for product -1.4656496501099787 (100/1296))
# Predicting 201904 for product -1.4629839873906785 (101/1296))
# Predicting 201904 for product -1.4603183246713785 (102/1296))
# Predicting 201904 for product -1.4576526619520784 (103/1296))
# Predicting 201904 for product -1.4549869992327784 (104/1296))
# Predicting 201904 for product -1.4523213365134782 (105/1296))
# Predicting 201904 for product -1.4496556737941781 (106/1296))
# Predicting 201904 for product -1.4469900110748781 (107/1296))
# Predicting 201904 for product -1.444324348355578 (108/1296))
# Predicting 201904 for product -1.4416586856362779 (109/1296))
# Predicting 201904 for product -1.4389930229169778 (110/1296))
# Predicting 201904 for product -1.4363273601976778 (111/1296))
# Predicting 201904 for product -1.4336616974783778 (112/1296))
# Predicting 201904 for product -1.4309960347590776 (113/1296))
# Predicting 201904 for product -1.4283303720397775 (114/1296))
# Predicting 201904 for product -1.4256647093204775 (115/1296))
# Predicting 201904 for product -1.4229990466011775 (116/1296))
# Predicting 201904 for product -1.4203333838818772 (117/1296))
# Predicting 201904 for product -1.4176677211625772 (118/1296))
# Predicting 201904 for product -1.4150020584432772 (119/1296))
# Predicting 201904 for product -1.4123363957239772 (120/1296))
# Predicting 201904 for product -1.409670733004677 (121/1296))
# Predicting 201904 for product -1.407005070285377 (122/1296))
# Predicting 201904 for product -1.404339407566077 (123/1296))
# Predicting 201904 for product -1.4016737448467769 (124/1296))
# Predicting 201904 for product -1.3990080821274766 (125/1296))
# Predicting 201904 for product -1.3963424194081766 (126/1296))
# Predicting 201904 for product -1.3936767566888766 (127/1296))
# Predicting 201904 for product -1.3910110939695766 (128/1296))
# Predicting 201904 for product -1.3883454312502763 (129/1296))
# Predicting 201904 for product -1.3856797685309763 (130/1296))
# Predicting 201904 for product -1.3830141058116763 (131/1296))
# Predicting 201904 for product -1.380348443092376 (132/1296))
# Predicting 201904 for product -1.377682780373076 (133/1296))
# Predicting 201904 for product -1.375017117653776 (134/1296))
# Predicting 201904 for product -1.372351454934476 (135/1296))
# Predicting 201904 for product -1.3696857922151757 (136/1296))
# Predicting 201904 for product -1.3670201294958757 (137/1296))
# Predicting 201904 for product -1.3643544667765757 (138/1296))
# Predicting 201904 for product -1.3616888040572757 (139/1296))
# Predicting 201904 for product -1.3590231413379754 (140/1296))
# Predicting 201904 for product -1.3563574786186754 (141/1296))
# Predicting 201904 for product -1.3536918158993754 (142/1296))
# Predicting 201904 for product -1.3510261531800754 (143/1296))
# Predicting 201904 for product -1.348360490460775 (144/1296))
# Predicting 201904 for product -1.345694827741475 (145/1296))
# Predicting 201904 for product -1.343029165022175 (146/1296))
# Predicting 201904 for product -1.340363502302875 (147/1296))
# Predicting 201904 for product -1.3376978395835748 (148/1296))
# Predicting 201904 for product -1.3350321768642748 (149/1296))
# Predicting 201904 for product -1.3323665141449748 (150/1296))
# Predicting 201904 for product -1.3297008514256747 (151/1296))
# Predicting 201904 for product -1.3270351887063745 (152/1296))
# Predicting 201904 for product -1.3243695259870745 (153/1296))
# Predicting 201904 for product -1.3217038632677744 (154/1296))
# Predicting 201904 for product -1.3190382005484744 (155/1296))
# Predicting 201904 for product -1.3163725378291742 (156/1296))
# Predicting 201904 for product -1.3137068751098742 (157/1296))
# Predicting 201904 for product -1.3110412123905741 (158/1296))
# Predicting 201904 for product -1.3083755496712741 (159/1296))
# Predicting 201904 for product -1.3057098869519739 (160/1296))
# Predicting 201904 for product -1.3030442242326739 (161/1296))
# Predicting 201904 for product -1.3003785615133738 (162/1296))
# Predicting 201904 for product -1.2977128987940738 (163/1296))
# Predicting 201904 for product -1.2950472360747736 (164/1296))
# Predicting 201904 for product -1.2923815733554735 (165/1296))
# Predicting 201904 for product -1.2897159106361735 (166/1296))
# Predicting 201904 for product -1.2870502479168735 (167/1296))
# Predicting 201904 for product -1.2843845851975733 (168/1296))
# Predicting 201904 for product -1.2817189224782732 (169/1296))
# Predicting 201904 for product -1.2790532597589732 (170/1296))
# Predicting 201904 for product -1.276387597039673 (171/1296))
# Predicting 201904 for product -1.273721934320373 (172/1296))
# Predicting 201904 for product -1.271056271601073 (173/1296))
# Predicting 201904 for product -1.268390608881773 (174/1296))
# Predicting 201904 for product -1.2657249461624727 (175/1296))
# Predicting 201904 for product -1.2630592834431726 (176/1296))
# Predicting 201904 for product -1.2603936207238726 (177/1296))
# Predicting 201904 for product -1.2577279580045726 (178/1296))
# Predicting 201904 for product -1.2550622952852724 (179/1296))
# Predicting 201904 for product -1.2523966325659723 (180/1296))
# Predicting 201904 for product -1.2497309698466723 (181/1296))
# Predicting 201904 for product -1.2470653071273723 (182/1296))
# Predicting 201904 for product -1.244399644408072 (183/1296))
# Predicting 201904 for product -1.241733981688772 (184/1296))
# Predicting 201904 for product -1.239068318969472 (185/1296))
# Predicting 201904 for product -1.236402656250172 (186/1296))
# Predicting 201904 for product -1.2337369935308717 (187/1296))
# Predicting 201904 for product -1.2310713308115717 (188/1296))
# Predicting 201904 for product -1.2284056680922717 (189/1296))
# Predicting 201904 for product -1.2257400053729717 (190/1296))
# Predicting 201904 for product -1.2230743426536714 (191/1296))
# Predicting 201904 for product -1.2204086799343714 (192/1296))
# Predicting 201904 for product -1.2177430172150714 (193/1296))
# Predicting 201904 for product -1.2150773544957714 (194/1296))
# Predicting 201904 for product -1.2124116917764711 (195/1296))
# Predicting 201904 for product -1.209746029057171 (196/1296))
# Predicting 201904 for product -1.207080366337871 (197/1296))
# Predicting 201904 for product -1.204414703618571 (198/1296))
# Predicting 201904 for product -1.2017490408992708 (199/1296))
# Predicting 201904 for product -1.1990833781799708 (200/1296))
# Predicting 201904 for product -1.1964177154606708 (201/1296))
# Predicting 201904 for product -1.1937520527413708 (202/1296))
# Predicting 201904 for product -1.1910863900220705 (203/1296))
# Predicting 201904 for product -1.1884207273027705 (204/1296))
# Predicting 201904 for product -1.1857550645834705 (205/1296))
# Predicting 201904 for product -1.1830894018641704 (206/1296))
# Predicting 201904 for product -1.1804237391448702 (207/1296))
# Predicting 201904 for product -1.1777580764255702 (208/1296))
# Predicting 201904 for product -1.1750924137062702 (209/1296))
# Predicting 201904 for product -1.1724267509869701 (210/1296))
# Predicting 201904 for product -1.16976108826767 (211/1296))
# Predicting 201904 for product -1.1670954255483699 (212/1296))
# Predicting 201904 for product -1.1644297628290698 (213/1296))
# Predicting 201904 for product -1.1617641001097696 (214/1296))
# Predicting 201904 for product -1.1590984373904696 (215/1296))
# Predicting 201904 for product -1.1564327746711696 (216/1296))
# Predicting 201904 for product -1.1537671119518695 (217/1296))
# Predicting 201904 for product -1.1511014492325693 (218/1296))
# Predicting 201904 for product -1.1484357865132693 (219/1296))
# Predicting 201904 for product -1.1457701237939693 (220/1296))
# Predicting 201904 for product -1.1431044610746692 (221/1296))
# Predicting 201904 for product -1.140438798355369 (222/1296))
# Predicting 201904 for product -1.137773135636069 (223/1296))
# Predicting 201904 for product -1.135107472916769 (224/1296))
# Predicting 201904 for product -1.132441810197469 (225/1296))
# Predicting 201904 for product -1.1297761474781687 (226/1296))
# Predicting 201904 for product -1.1271104847588687 (227/1296))
# Predicting 201904 for product -1.1244448220395686 (228/1296))
# Predicting 201904 for product -1.1217791593202686 (229/1296))
# Predicting 201904 for product -1.1191134966009684 (230/1296))
# Predicting 201904 for product -1.1164478338816684 (231/1296))
# Predicting 201904 for product -1.1137821711623683 (232/1296))
# Predicting 201904 for product -1.1111165084430683 (233/1296))
# Predicting 201904 for product -1.108450845723768 (234/1296))
# Predicting 201904 for product -1.105785183004468 (235/1296))
# Predicting 201904 for product -1.103119520285168 (236/1296))
# Predicting 201904 for product -1.100453857565868 (237/1296))
# Predicting 201904 for product -1.0977881948465678 (238/1296))
# Predicting 201904 for product -1.0951225321272677 (239/1296))
# Predicting 201904 for product -1.0924568694079677 (240/1296))
# Predicting 201904 for product -1.0897912066886677 (241/1296))
# Predicting 201904 for product -1.0871255439693674 (242/1296))
# Predicting 201904 for product -1.0844598812500674 (243/1296))
# Predicting 201904 for product -1.0817942185307674 (244/1296))
# Predicting 201904 for product -1.0791285558114674 (245/1296))
# Predicting 201904 for product -1.0764628930921671 (246/1296))
# Predicting 201904 for product -1.0737972303728671 (247/1296))
# Predicting 201904 for product -1.071131567653567 (248/1296))
# Predicting 201904 for product -1.068465904934267 (249/1296))
# Predicting 201904 for product -1.0658002422149668 (250/1296))
# Predicting 201904 for product -1.0631345794956668 (251/1296))
# Predicting 201904 for product -1.0604689167763668 (252/1296))
# Predicting 201904 for product -1.0578032540570668 (253/1296))
# Predicting 201904 for product -1.0551375913377665 (254/1296))
# Predicting 201904 for product -1.0524719286184665 (255/1296))
# Predicting 201904 for product -1.0498062658991665 (256/1296))
# Predicting 201904 for product -1.0471406031798662 (257/1296))
# Predicting 201904 for product -1.0444749404605662 (258/1296))
# Predicting 201904 for product -1.0418092777412662 (259/1296))
# Predicting 201904 for product -1.0391436150219662 (260/1296))
# Predicting 201904 for product -1.036477952302666 (261/1296))
# Predicting 201904 for product -1.033812289583366 (262/1296))
# Predicting 201904 for product -1.0311466268640659 (263/1296))
# Predicting 201904 for product -1.0284809641447659 (264/1296))
# Predicting 201904 for product -1.0258153014254656 (265/1296))
# Predicting 201904 for product -1.0231496387061656 (266/1296))
# Predicting 201904 for product -1.0204839759868656 (267/1296))
# Predicting 201904 for product -1.0178183132675656 (268/1296))
# Predicting 201904 for product -1.0151526505482653 (269/1296))
# Predicting 201904 for product -1.0124869878289653 (270/1296))
# Predicting 201904 for product -1.0098213251096653 (271/1296))
# Predicting 201904 for product -1.0071556623903652 (272/1296))
# Predicting 201904 for product -1.004489999671065 (273/1296))
# Predicting 201904 for product -1.001824336951765 (274/1296))
# Predicting 201904 for product -0.999158674232465 (275/1296))
# Predicting 201904 for product -0.9964930115131648 (276/1296))
# Predicting 201904 for product -0.9938273487938648 (277/1296))
# Predicting 201904 for product -0.9911616860745647 (278/1296))
# Predicting 201904 for product -0.9884960233552647 (279/1296))
# Predicting 201904 for product -0.9858303606359645 (280/1296))
# Predicting 201904 for product -0.9831646979166645 (281/1296))
# Predicting 201904 for product -0.9804990351973644 (282/1296))
# Predicting 201904 for product -0.9778333724780643 (283/1296))
# Predicting 201904 for product -0.9751677097587642 (284/1296))
# Predicting 201904 for product -0.9725020470394642 (285/1296))
# Predicting 201904 for product -0.9698363843201641 (286/1296))
# Predicting 201904 for product -0.967170721600864 (287/1296))
# Predicting 201904 for product -0.9645050588815639 (288/1296))
# Predicting 201904 for product -0.9618393961622639 (289/1296))
# Predicting 201904 for product -0.9591737334429637 (290/1296))
# Predicting 201904 for product -0.9565080707236637 (291/1296))
# Predicting 201904 for product -0.9538424080043636 (292/1296))
# Predicting 201904 for product -0.9511767452850636 (293/1296))
# Predicting 201904 for product -0.9485110825657634 (294/1296))
# Predicting 201904 for product -0.9458454198464634 (295/1296))
# Predicting 201904 for product -0.9431797571271633 (296/1296))
# Predicting 201904 for product -0.9405140944078632 (297/1296))
# Predicting 201904 for product -0.9378484316885631 (298/1296))
# Predicting 201904 for product -0.935182768969263 (299/1296))
# Predicting 201904 for product -0.932517106249963 (300/1296))
# Predicting 201904 for product -0.9298514435306628 (301/1296))
# Predicting 201904 for product -0.9271857808113628 (302/1296))
# Predicting 201904 for product -0.9245201180920627 (303/1296))
# Predicting 201904 for product -0.9218544553727627 (304/1296))
# Predicting 201904 for product -0.9191887926534625 (305/1296))
# Predicting 201904 for product -0.9165231299341625 (306/1296))
# Predicting 201904 for product -0.9138574672148624 (307/1296))
# Predicting 201904 for product -0.9111918044955624 (308/1296))
# Predicting 201904 for product -0.9085261417762622 (309/1296))
# Predicting 201904 for product -0.9058604790569622 (310/1296))
# Predicting 201904 for product -0.9031948163376621 (311/1296))
# Predicting 201904 for product -0.900529153618362 (312/1296))
# Predicting 201904 for product -0.8978634908990619 (313/1296))
# Predicting 201904 for product -0.8951978281797619 (314/1296))
# Predicting 201904 for product -0.8925321654604618 (315/1296))
# Predicting 201904 for product -0.8898665027411617 (316/1296))
# Predicting 201904 for product -0.8872008400218616 (317/1296))
# Predicting 201904 for product -0.8845351773025616 (318/1296))
# Predicting 201904 for product -0.8818695145832615 (319/1296))
# Predicting 201904 for product -0.8792038518639614 (320/1296))
# Predicting 201904 for product -0.8765381891446613 (321/1296))
# Predicting 201904 for product -0.8738725264253613 (322/1296))
# Predicting 201904 for product -0.8712068637060612 (323/1296))
# Predicting 201904 for product -0.8685412009867611 (324/1296))
# Predicting 201904 for product -0.865875538267461 (325/1296))
# Predicting 201904 for product -0.863209875548161 (326/1296))
# Predicting 201904 for product -0.8605442128288608 (327/1296))
# Predicting 201904 for product -0.8578785501095608 (328/1296))
# Predicting 201904 for product -0.8552128873902607 (329/1296))
# Predicting 201904 for product -0.8525472246709607 (330/1296))
# Predicting 201904 for product -0.8498815619516605 (331/1296))
# Predicting 201904 for product -0.8472158992323605 (332/1296))
# Predicting 201904 for product -0.8445502365130604 (333/1296))
# Predicting 201904 for product -0.8418845737937604 (334/1296))
# Predicting 201904 for product -0.8392189110744602 (335/1296))
# Predicting 201904 for product -0.8365532483551602 (336/1296))
# Predicting 201904 for product -0.8338875856358601 (337/1296))
# Predicting 201904 for product -0.83122192291656 (338/1296))
# Predicting 201904 for product -0.8285562601972599 (339/1296))
# Predicting 201904 for product -0.8258905974779598 (340/1296))
# Predicting 201904 for product -0.8232249347586598 (341/1296))
# Predicting 201904 for product -0.8205592720393596 (342/1296))
# Predicting 201904 for product -0.8178936093200596 (343/1296))
# Predicting 201904 for product -0.8152279466007595 (344/1296))
# Predicting 201904 for product -0.8125622838814595 (345/1296))
# Predicting 201904 for product -0.8098966211621593 (346/1296))
# Predicting 201904 for product -0.8072309584428593 (347/1296))
# Predicting 201904 for product -0.8045652957235592 (348/1296))
# Predicting 201904 for product -0.8018996330042591 (349/1296))
# Predicting 201904 for product -0.799233970284959 (350/1296))
# Predicting 201904 for product -0.796568307565659 (351/1296))
# Predicting 201904 for product -0.7939026448463589 (352/1296))
# Predicting 201904 for product -0.7912369821270588 (353/1296))
# Predicting 201904 for product -0.7885713194077587 (354/1296))
# Predicting 201904 for product -0.7859056566884587 (355/1296))
# Predicting 201904 for product -0.7832399939691586 (356/1296))
# Predicting 201904 for product -0.7805743312498585 (357/1296))
# Predicting 201904 for product -0.7779086685305584 (358/1296))
# Predicting 201904 for product -0.7752430058112584 (359/1296))
# Predicting 201904 for product -0.7725773430919582 (360/1296))
# Predicting 201904 for product -0.7699116803726582 (361/1296))
# Predicting 201904 for product -0.7672460176533581 (362/1296))
# Predicting 201904 for product -0.7645803549340581 (363/1296))
# Predicting 201904 for product -0.7619146922147579 (364/1296))
# Predicting 201904 for product -0.7592490294954579 (365/1296))
# Predicting 201904 for product -0.7565833667761578 (366/1296))
# Predicting 201904 for product -0.7539177040568578 (367/1296))
# Predicting 201904 for product -0.7512520413375576 (368/1296))
# Predicting 201904 for product -0.7485863786182576 (369/1296))
# Predicting 201904 for product -0.7459207158989575 (370/1296))
# Predicting 201904 for product -0.7432550531796575 (371/1296))
# Predicting 201904 for product -0.7405893904603573 (372/1296))
# Predicting 201904 for product -0.7379237277410573 (373/1296))
# Predicting 201904 for product -0.7352580650217572 (374/1296))
# Predicting 201904 for product -0.7325924023024571 (375/1296))
# Predicting 201904 for product -0.729926739583157 (376/1296))
# Predicting 201904 for product -0.727261076863857 (377/1296))
# Predicting 201904 for product -0.7245954141445569 (378/1296))
# Predicting 201904 for product -0.7219297514252568 (379/1296))
# Predicting 201904 for product -0.7192640887059567 (380/1296))
# Predicting 201904 for product -0.7165984259866567 (381/1296))
# Predicting 201904 for product -0.7139327632673566 (382/1296))
# Predicting 201904 for product -0.7112671005480564 (383/1296))
# Predicting 201904 for product -0.7086014378287564 (384/1296))
# Predicting 201904 for product -0.7059357751094563 (385/1296))
# Predicting 201904 for product -0.7032701123901562 (386/1296))
# Predicting 201904 for product -0.7006044496708561 (387/1296))
# Predicting 201904 for product -0.6979387869515561 (388/1296))
# Predicting 201904 for product -0.695273124232256 (389/1296))
# Predicting 201904 for product -0.6926074615129559 (390/1296))
# Predicting 201904 for product -0.6899417987936558 (391/1296))
# Predicting 201904 for product -0.6872761360743558 (392/1296))
# Predicting 201904 for product -0.6846104733550556 (393/1296))
# Predicting 201904 for product -0.6819448106357556 (394/1296))
# Predicting 201904 for product -0.6792791479164555 (395/1296))
# Predicting 201904 for product -0.6766134851971555 (396/1296))
# Predicting 201904 for product -0.6739478224778553 (397/1296))
# Predicting 201904 for product -0.6712821597585553 (398/1296))
# Predicting 201904 for product -0.6686164970392552 (399/1296))
# Predicting 201904 for product -0.6659508343199552 (400/1296))
# Predicting 201904 for product -0.663285171600655 (401/1296))
# Predicting 201904 for product -0.660619508881355 (402/1296))
# Predicting 201904 for product -0.6579538461620549 (403/1296))
# Predicting 201904 for product -0.6552881834427549 (404/1296))
# Predicting 201904 for product -0.6526225207234547 (405/1296))
# Predicting 201904 for product -0.6499568580041547 (406/1296))
# Predicting 201904 for product -0.6472911952848546 (407/1296))
# Predicting 201904 for product -0.6446255325655545 (408/1296))
# Predicting 201904 for product -0.6419598698462544 (409/1296))
# Predicting 201904 for product -0.6392942071269544 (410/1296))
# Predicting 201904 for product -0.6366285444076543 (411/1296))
# Predicting 201904 for product -0.6339628816883542 (412/1296))
# Predicting 201904 for product -0.6312972189690541 (413/1296))
# Predicting 201904 for product -0.6286315562497541 (414/1296))
# Predicting 201904 for product -0.625965893530454 (415/1296))
# Predicting 201904 for product -0.6233002308111539 (416/1296))
# Predicting 201904 for product -0.6206345680918538 (417/1296))
# Predicting 201904 for product -0.6179689053725538 (418/1296))
# Predicting 201904 for product -0.6153032426532536 (419/1296))
# Predicting 201904 for product -0.6126375799339536 (420/1296))
# Predicting 201904 for product -0.6099719172146535 (421/1296))
# Predicting 201904 for product -0.6073062544953535 (422/1296))
# Predicting 201904 for product -0.6046405917760533 (423/1296))
# Predicting 201904 for product -0.6019749290567532 (424/1296))
# Predicting 201904 for product -0.5993092663374532 (425/1296))
# Predicting 201904 for product -0.596643603618153 (426/1296))
# Predicting 201904 for product -0.593977940898853 (427/1296))
# Predicting 201904 for product -0.5913122781795529 (428/1296))
# Predicting 201904 for product -0.5886466154602529 (429/1296))
# Predicting 201904 for product -0.5859809527409527 (430/1296))
# Predicting 201904 for product -0.5833152900216527 (431/1296))
# Predicting 201904 for product -0.5806496273023526 (432/1296))
# Predicting 201904 for product -0.5779839645830526 (433/1296))
# Predicting 201904 for product -0.5753183018637524 (434/1296))
# Predicting 201904 for product -0.5726526391444524 (435/1296))
# Predicting 201904 for product -0.5699869764251523 (436/1296))
# Predicting 201904 for product -0.5673213137058523 (437/1296))
# Predicting 201904 for product -0.5646556509865521 (438/1296))
# Predicting 201904 for product -0.5619899882672521 (439/1296))
# Predicting 201904 for product -0.559324325547952 (440/1296))
# Predicting 201904 for product -0.556658662828652 (441/1296))
# Predicting 201904 for product -0.5539930001093518 (442/1296))
# Predicting 201904 for product -0.5513273373900518 (443/1296))
# Predicting 201904 for product -0.5486616746707517 (444/1296))
# Predicting 201904 for product -0.5459960119514516 (445/1296))
# Predicting 201904 for product -0.5433303492321515 (446/1296))
# Predicting 201904 for product -0.5406646865128515 (447/1296))
# Predicting 201904 for product -0.5379990237935514 (448/1296))
# Predicting 201904 for product -0.5353333610742513 (449/1296))
# Predicting 201904 for product -0.5326676983549512 (450/1296))
# Predicting 201904 for product -0.5300020356356512 (451/1296))
# Predicting 201904 for product -0.527336372916351 (452/1296))
# Predicting 201904 for product -0.524670710197051 (453/1296))
# Predicting 201904 for product -0.5220050474777509 (454/1296))
# Predicting 201904 for product -0.5193393847584509 (455/1296))
# Predicting 201904 for product -0.5166737220391507 (456/1296))
# Predicting 201904 for product -0.5140080593198507 (457/1296))
# Predicting 201904 for product -0.5113423966005506 (458/1296))
# Predicting 201904 for product -0.5086767338812506 (459/1296))
# Predicting 201904 for product -0.5060110711619504 (460/1296))
# Predicting 201904 for product -0.5033454084426504 (461/1296))
# Predicting 201904 for product -0.5006797457233503 (462/1296))
# Predicting 201904 for product -0.4980140830040502 (463/1296))
# Predicting 201904 for product -0.4953484202847501 (464/1296))
# Predicting 201904 for product -0.49268275756545005 (465/1296))
# Predicting 201904 for product -0.49001709484614997 (466/1296))
# Predicting 201904 for product -0.4873514321268499 (467/1296))
# Predicting 201904 for product -0.4846857694075498 (468/1296))
# Predicting 201904 for product -0.48202010668824974 (469/1296))
# Predicting 201904 for product -0.47935444396894966 (470/1296))
# Predicting 201904 for product -0.4766887812496496 (471/1296))
# Predicting 201904 for product -0.4740231185303495 (472/1296))
# Predicting 201904 for product -0.47135745581104943 (473/1296))
# Predicting 201904 for product -0.46869179309174935 (474/1296))
# Predicting 201904 for product -0.4660261303724493 (475/1296))
# Predicting 201904 for product -0.4633604676531492 (476/1296))
# Predicting 201904 for product -0.4606948049338491 (477/1296))
# Predicting 201904 for product -0.45802914221454905 (478/1296))
# Predicting 201904 for product -0.45536347949524897 (479/1296))
# Predicting 201904 for product -0.4526978167759489 (480/1296))
# Predicting 201904 for product -0.4500321540566488 (481/1296))
# Predicting 201904 for product -0.44736649133734874 (482/1296))
# Predicting 201904 for product -0.44470082861804866 (483/1296))
# Predicting 201904 for product -0.4420351658987486 (484/1296))
# Predicting 201904 for product -0.4393695031794485 (485/1296))
# Predicting 201904 for product -0.43670384046014843 (486/1296))
# Predicting 201904 for product -0.4340381777408483 (487/1296))
# Predicting 201904 for product -0.4313725150215482 (488/1296))
# Predicting 201904 for product -0.42870685230224814 (489/1296))
# Predicting 201904 for product -0.42604118958294807 (490/1296))
# Predicting 201904 for product -0.423375526863648 (491/1296))
# Predicting 201904 for product -0.4207098641443479 (492/1296))
# Predicting 201904 for product -0.41804420142504783 (493/1296))
# Predicting 201904 for product -0.41537853870574776 (494/1296))
# Predicting 201904 for product -0.4127128759864477 (495/1296))
# Predicting 201904 for product -0.4100472132671476 (496/1296))
# Predicting 201904 for product -0.4073815505478475 (497/1296))
# Predicting 201904 for product -0.40471588782854745 (498/1296))
# Predicting 201904 for product -0.40205022510924737 (499/1296))
# Predicting 201904 for product -0.3993845623899473 (500/1296))
# Predicting 201904 for product -0.3967188996706472 (501/1296))
# Predicting 201904 for product -0.39405323695134714 (502/1296))
# Predicting 201904 for product -0.39138757423204706 (503/1296))
# Predicting 201904 for product -0.388721911512747 (504/1296))
# Predicting 201904 for product -0.3860562487934469 (505/1296))
# Predicting 201904 for product -0.38339058607414683 (506/1296))
# Predicting 201904 for product -0.38072492335484676 (507/1296))
# Predicting 201904 for product -0.3780592606355467 (508/1296))
# Predicting 201904 for product -0.3753935979162466 (509/1296))
# Predicting 201904 for product -0.3727279351969465 (510/1296))
# Predicting 201904 for product -0.37006227247764645 (511/1296))
# Predicting 201904 for product -0.36739660975834637 (512/1296))
# Predicting 201904 for product -0.3647309470390463 (513/1296))
# Predicting 201904 for product -0.3620652843197462 (514/1296))
# Predicting 201904 for product -0.35939962160044614 (515/1296))
# Predicting 201904 for product -0.35673395888114606 (516/1296))
# Predicting 201904 for product -0.354068296161846 (517/1296))
# Predicting 201904 for product -0.34607130800394575 (518/1296))
# Predicting 201904 for product -0.3434056452846457 (519/1296))
# Predicting 201904 for product -0.3407399825653456 (520/1296))
# Predicting 201904 for product -0.3380743198460455 (521/1296))
# Predicting 201904 for product -0.33540865712674545 (522/1296))
# Predicting 201904 for product -0.33274299440744537 (523/1296))
# Predicting 201904 for product -0.3300773316881453 (524/1296))
# Predicting 201904 for product -0.3274116689688452 (525/1296))
# Predicting 201904 for product -0.32474600624954514 (526/1296))
# Predicting 201904 for product -0.322080343530245 (527/1296))
# Predicting 201904 for product -0.31941468081094493 (528/1296))
# Predicting 201904 for product -0.31674901809164485 (529/1296))
# Predicting 201904 for product -0.3140833553723448 (530/1296))
# Predicting 201904 for product -0.3114176926530447 (531/1296))
# Predicting 201904 for product -0.3087520299337446 (532/1296))
# Predicting 201904 for product -0.30608636721444454 (533/1296))
# Predicting 201904 for product -0.30342070449514447 (534/1296))
# Predicting 201904 for product -0.3007550417758444 (535/1296))
# Predicting 201904 for product -0.2980893790565443 (536/1296))
# Predicting 201904 for product -0.29542371633724424 (537/1296))
# Predicting 201904 for product -0.29275805361794416 (538/1296))
# Predicting 201904 for product -0.2900923908986441 (539/1296))
# Predicting 201904 for product -0.287426728179344 (540/1296))
# Predicting 201904 for product -0.2847610654600439 (541/1296))
# Predicting 201904 for product -0.28209540274074385 (542/1296))
# Predicting 201904 for product -0.2794297400214438 (543/1296))
# Predicting 201904 for product -0.2767640773021437 (544/1296))
# Predicting 201904 for product -0.2740984145828436 (545/1296))
# Predicting 201904 for product -0.27143275186354354 (546/1296))
# Predicting 201904 for product -0.26876708914424347 (547/1296))
# Predicting 201904 for product -0.2661014264249434 (548/1296))
# Predicting 201904 for product -0.2634357637056433 (549/1296))
# Predicting 201904 for product -0.26077010098634323 (550/1296))
# Predicting 201904 for product -0.25810443826704316 (551/1296))
# Predicting 201904 for product -0.2554387755477431 (552/1296))
# Predicting 201904 for product -0.252773112828443 (553/1296))
# Predicting 201904 for product -0.2501074501091429 (554/1296))
# Predicting 201904 for product -0.24744178738984285 (555/1296))
# Predicting 201904 for product -0.24477612467054277 (556/1296))
# Predicting 201904 for product -0.2421104619512427 (557/1296))
# Predicting 201904 for product -0.2394447992319426 (558/1296))
# Predicting 201904 for product -0.2367791365126425 (559/1296))
# Predicting 201904 for product -0.23411347379334244 (560/1296))
# Predicting 201904 for product -0.23144781107404236 (561/1296))
# Predicting 201904 for product -0.22878214835474228 (562/1296))
# Predicting 201904 for product -0.2261164856354422 (563/1296))
# Predicting 201904 for product -0.22345082291614213 (564/1296))
# Predicting 201904 for product -0.22078516019684205 (565/1296))
# Predicting 201904 for product -0.21811949747754197 (566/1296))
# Predicting 201904 for product -0.2154538347582419 (567/1296))
# Predicting 201904 for product -0.21278817203894182 (568/1296))
# Predicting 201904 for product -0.21012250931964174 (569/1296))
# Predicting 201904 for product -0.20745684660034167 (570/1296))
# Predicting 201904 for product -0.2047911838810416 (571/1296))
# Predicting 201904 for product -0.2021255211617415 (572/1296))
# Predicting 201904 for product -0.19945985844244143 (573/1296))
# Predicting 201904 for product -0.19679419572314136 (574/1296))
# Predicting 201904 for product -0.19412853300384128 (575/1296))
# Predicting 201904 for product -0.1914628702845412 (576/1296))
# Predicting 201904 for product -0.18879720756524113 (577/1296))
# Predicting 201904 for product -0.18613154484594105 (578/1296))
# Predicting 201904 for product -0.18346588212664094 (579/1296))
# Predicting 201904 for product -0.18080021940734087 (580/1296))
# Predicting 201904 for product -0.1781345566880408 (581/1296))
# Predicting 201904 for product -0.1754688939687407 (582/1296))
# Predicting 201904 for product -0.17280323124944064 (583/1296))
# Predicting 201904 for product -0.17013756853014056 (584/1296))
# Predicting 201904 for product -0.16747190581084048 (585/1296))
# Predicting 201904 for product -0.1648062430915404 (586/1296))
# Predicting 201904 for product -0.16214058037224033 (587/1296))
# Predicting 201904 for product -0.15947491765294025 (588/1296))
# Predicting 201904 for product -0.15680925493364017 (589/1296))
# Predicting 201904 for product -0.1541435922143401 (590/1296))
# Predicting 201904 for product -0.15147792949504002 (591/1296))
# Predicting 201904 for product -0.14881226677573994 (592/1296))
# Predicting 201904 for product -0.14614660405643987 (593/1296))
# Predicting 201904 for product -0.1434809413371398 (594/1296))
# Predicting 201904 for product -0.1408152786178397 (595/1296))
# Predicting 201904 for product -0.13814961589853963 (596/1296))
# Predicting 201904 for product -0.13548395317923956 (597/1296))
# Predicting 201904 for product -0.13281829045993948 (598/1296))
# Predicting 201904 for product -0.1301526277406394 (599/1296))
# Predicting 201904 for product -0.12748696502133933 (600/1296))
# Predicting 201904 for product -0.12482130230203924 (601/1296))
# Predicting 201904 for product -0.12215563958273916 (602/1296))
# Predicting 201904 for product -0.11948997686343908 (603/1296))
# Predicting 201904 for product -0.116824314144139 (604/1296))
# Predicting 201904 for product -0.11415865142483893 (605/1296))
# Predicting 201904 for product -0.11149298870553884 (606/1296))
# Predicting 201904 for product -0.10882732598623876 (607/1296))
# Predicting 201904 for product -0.10616166326693868 (608/1296))
# Predicting 201904 for product -0.1034960005476386 (609/1296))
# Predicting 201904 for product -0.10083033782833853 (610/1296))
# Predicting 201904 for product -0.09816467510903845 (611/1296))
# Predicting 201904 for product -0.09549901238973837 (612/1296))
# Predicting 201904 for product -0.0928333496704383 (613/1296))
# Predicting 201904 for product -0.09016768695113822 (614/1296))
# Predicting 201904 for product -0.08750202423183814 (615/1296))
# Predicting 201904 for product -0.08483636151253805 (616/1296))
# Predicting 201904 for product -0.08217069879323798 (617/1296))
# Predicting 201904 for product -0.0795050360739379 (618/1296))
# Predicting 201904 for product -0.07683937335463782 (619/1296))
# Predicting 201904 for product -0.07417371063533774 (620/1296))
# Predicting 201904 for product -0.07150804791603767 (621/1296))
# Predicting 201904 for product -0.06884238519673759 (622/1296))
# Predicting 201904 for product -0.06617672247743751 (623/1296))
# Predicting 201904 for product -0.06351105975813744 (624/1296))
# Predicting 201904 for product -0.06084539703883735 (625/1296))
# Predicting 201904 for product -0.058179734319537275 (626/1296))
# Predicting 201904 for product -0.0555140716002372 (627/1296))
# Predicting 201904 for product -0.05284840888093712 (628/1296))
# Predicting 201904 for product -0.05018274616163704 (629/1296))
# Predicting 201904 for product -0.04751708344233696 (630/1296))
# Predicting 201904 for product -0.04485142072303688 (631/1296))
# Predicting 201904 for product -0.042185758003736806 (632/1296))
# Predicting 201904 for product -0.03952009528443673 (633/1296))
# Predicting 201904 for product -0.03685443256513665 (634/1296))
# Predicting 201904 for product -0.03418876984583657 (635/1296))
# Predicting 201904 for product -0.03152310712653649 (636/1296))
# Predicting 201904 for product -0.028857444407236414 (637/1296))
# Predicting 201904 for product -0.026191781687936337 (638/1296))
# Predicting 201904 for product -0.023526118968636257 (639/1296))
# Predicting 201904 for product -0.02086045624933618 (640/1296))
# Predicting 201904 for product -0.0181947935300361 (641/1296))
# Predicting 201904 for product -0.015529130810736022 (642/1296))
# Predicting 201904 for product -0.012863468091435943 (643/1296))
# Predicting 201904 for product -0.010197805372135866 (644/1296))
# Predicting 201904 for product -0.0075321426528357875 (645/1296))
# Predicting 201904 for product -0.004866479933535709 (646/1296))
# Predicting 201904 for product -0.0022008172142356304 (647/1296))
# Predicting 201904 for product 0.0004648455050644479 (648/1296))
# Predicting 201904 for product 0.0031305082243645263 (649/1296))
# Predicting 201904 for product 0.005796170943664605 (650/1296))
# Predicting 201904 for product 0.008461833662964683 (651/1296))
# Predicting 201904 for product 0.011127496382264762 (652/1296))
# Predicting 201904 for product 0.01379315910156484 (653/1296))
# Predicting 201904 for product 0.01645882182086492 (654/1296))
# Predicting 201904 for product 0.019124484540164997 (655/1296))
# Predicting 201904 for product 0.021790147259465074 (656/1296))
# Predicting 201904 for product 0.024455809978765154 (657/1296))
# Predicting 201904 for product 0.02712147269806523 (658/1296))
# Predicting 201904 for product 0.02978713541736531 (659/1296))
# Predicting 201904 for product 0.032452798136665385 (660/1296))
# Predicting 201904 for product 0.03511846085596547 (661/1296))
# Predicting 201904 for product 0.037784123575265546 (662/1296))
# Predicting 201904 for product 0.04044978629456562 (663/1296))
# Predicting 201904 for product 0.0431154490138657 (664/1296))
# Predicting 201904 for product 0.04578111173316578 (665/1296))
# Predicting 201904 for product 0.04844677445246586 (666/1296))
# Predicting 201904 for product 0.05111243717176594 (667/1296))
# Predicting 201904 for product 0.053778099891066015 (668/1296))
# Predicting 201904 for product 0.05644376261036609 (669/1296))
# Predicting 201904 for product 0.05910942532966617 (670/1296))
# Predicting 201904 for product 0.06177508804896625 (671/1296))
# Predicting 201904 for product 0.06444075076826633 (672/1296))
# Predicting 201904 for product 0.06710641348756641 (673/1296))
# Predicting 201904 for product 0.06977207620686648 (674/1296))
# Predicting 201904 for product 0.07243773892616656 (675/1296))
# Predicting 201904 for product 0.07510340164546664 (676/1296))
# Predicting 201904 for product 0.07776906436476672 (677/1296))
# Predicting 201904 for product 0.08043472708406679 (678/1296))
# Predicting 201904 for product 0.08310038980336688 (679/1296))
# Predicting 201904 for product 0.08576605252266696 (680/1296))
# Predicting 201904 for product 0.08843171524196704 (681/1296))
# Predicting 201904 for product 0.09109737796126711 (682/1296))
# Predicting 201904 for product 0.09376304068056719 (683/1296))
# Predicting 201904 for product 0.09642870339986727 (684/1296))
# Predicting 201904 for product 0.09909436611916735 (685/1296))
# Predicting 201904 for product 0.10176002883846742 (686/1296))
# Predicting 201904 for product 0.1044256915577675 (687/1296))
# Predicting 201904 for product 0.10709135427706758 (688/1296))
# Predicting 201904 for product 0.10975701699636765 (689/1296))
# Predicting 201904 for product 0.11242267971566774 (690/1296))
# Predicting 201904 for product 0.11508834243496782 (691/1296))
# Predicting 201904 for product 0.1177540051542679 (692/1296))
# Predicting 201904 for product 0.12041966787356798 (693/1296))
# Predicting 201904 for product 0.12308533059286805 (694/1296))
# Predicting 201904 for product 0.12575099331216813 (695/1296))
# Predicting 201904 for product 0.1284166560314682 (696/1296))
# Predicting 201904 for product 0.13108231875076828 (697/1296))
# Predicting 201904 for product 0.13374798147006836 (698/1296))
# Predicting 201904 for product 0.13641364418936844 (699/1296))
# Predicting 201904 for product 0.13907930690866852 (700/1296))
# Predicting 201904 for product 0.1417449696279686 (701/1296))
# Predicting 201904 for product 0.14441063234726867 (702/1296))
# Predicting 201904 for product 0.14707629506656875 (703/1296))
# Predicting 201904 for product 0.14974195778586882 (704/1296))
# Predicting 201904 for product 0.1524076205051689 (705/1296))
# Predicting 201904 for product 0.155073283224469 (706/1296))
# Predicting 201904 for product 0.15773894594376908 (707/1296))
# Predicting 201904 for product 0.16040460866306916 (708/1296))
# Predicting 201904 for product 0.16307027138236924 (709/1296))
# Predicting 201904 for product 0.1657359341016693 (710/1296))
# Predicting 201904 for product 0.1684015968209694 (711/1296))
# Predicting 201904 for product 0.17106725954026947 (712/1296))
# Predicting 201904 for product 0.17373292225956954 (713/1296))
# Predicting 201904 for product 0.17639858497886962 (714/1296))
# Predicting 201904 for product 0.1790642476981697 (715/1296))
# Predicting 201904 for product 0.18172991041746978 (716/1296))
# Predicting 201904 for product 0.18439557313676985 (717/1296))
# Predicting 201904 for product 0.18706123585606993 (718/1296))
# Predicting 201904 for product 0.18972689857537 (719/1296))
# Predicting 201904 for product 0.19239256129467008 (720/1296))
# Predicting 201904 for product 0.19505822401397016 (721/1296))
# Predicting 201904 for product 0.19772388673327024 (722/1296))
# Predicting 201904 for product 0.20038954945257031 (723/1296))
# Predicting 201904 for product 0.2030552121718704 (724/1296))
# Predicting 201904 for product 0.20572087489117047 (725/1296))
# Predicting 201904 for product 0.20838653761047055 (726/1296))
# Predicting 201904 for product 0.21105220032977065 (727/1296))
# Predicting 201904 for product 0.21371786304907073 (728/1296))
# Predicting 201904 for product 0.2163835257683708 (729/1296))
# Predicting 201904 for product 0.21904918848767088 (730/1296))
# Predicting 201904 for product 0.22171485120697096 (731/1296))
# Predicting 201904 for product 0.22438051392627104 (732/1296))
# Predicting 201904 for product 0.2270461766455711 (733/1296))
# Predicting 201904 for product 0.2297118393648712 (734/1296))
# Predicting 201904 for product 0.23237750208417127 (735/1296))
# Predicting 201904 for product 0.23504316480347134 (736/1296))
# Predicting 201904 for product 0.23770882752277142 (737/1296))
# Predicting 201904 for product 0.2403744902420715 (738/1296))
# Predicting 201904 for product 0.24304015296137157 (739/1296))
# Predicting 201904 for product 0.24570581568067165 (740/1296))
# Predicting 201904 for product 0.24837147839997173 (741/1296))
# Predicting 201904 for product 0.25103714111927183 (742/1296))
# Predicting 201904 for product 0.2537028038385719 (743/1296))
# Predicting 201904 for product 0.256368466557872 (744/1296))
# Predicting 201904 for product 0.25903412927717206 (745/1296))
# Predicting 201904 for product 0.26169979199647214 (746/1296))
# Predicting 201904 for product 0.2643654547157722 (747/1296))
# Predicting 201904 for product 0.2670311174350723 (748/1296))
# Predicting 201904 for product 0.2696967801543724 (749/1296))
# Predicting 201904 for product 0.27236244287367245 (750/1296))
# Predicting 201904 for product 0.2750281055929725 (751/1296))
# Predicting 201904 for product 0.2776937683122726 (752/1296))
# Predicting 201904 for product 0.2803594310315727 (753/1296))
# Predicting 201904 for product 0.28302509375087276 (754/1296))
# Predicting 201904 for product 0.28569075647017284 (755/1296))
# Predicting 201904 for product 0.2883564191894729 (756/1296))
# Predicting 201904 for product 0.291022081908773 (757/1296))
# Predicting 201904 for product 0.29368774462807307 (758/1296))
# Predicting 201904 for product 0.29635340734737314 (759/1296))
# Predicting 201904 for product 0.2990190700666732 (760/1296))
# Predicting 201904 for product 0.3016847327859733 (761/1296))
# Predicting 201904 for product 0.3043503955052734 (762/1296))
# Predicting 201904 for product 0.30701605822457345 (763/1296))
# Predicting 201904 for product 0.30968172094387353 (764/1296))
# Predicting 201904 for product 0.3123473836631736 (765/1296))
# Predicting 201904 for product 0.3150130463824737 (766/1296))
# Predicting 201904 for product 0.31767870910177376 (767/1296))
# Predicting 201904 for product 0.32034437182107384 (768/1296))
# Predicting 201904 for product 0.3230100345403739 (769/1296))
# Predicting 201904 for product 0.325675697259674 (770/1296))
# Predicting 201904 for product 0.32834135997897407 (771/1296))
# Predicting 201904 for product 0.33100702269827414 (772/1296))
# Predicting 201904 for product 0.3336726854175742 (773/1296))
# Predicting 201904 for product 0.3363383481368743 (774/1296))
# Predicting 201904 for product 0.3390040108561744 (775/1296))
# ...
# Predicting 201904 for product 1.040073306032095 (1038/1296))
# Predicting 201904 for product 1.042738968751395 (1039/1296))
# Predicting 201904 for product 1.045404631470695 (1040/1296))
# Predicting 201904 for product 1.0480702941899953 (1041/1296))
# Predicting 201904 for product 1.0507359569092953 (1042/1296))
# Predicting 201904 for product 1.0534016196285954 (1043/1296))
# Predicting 201904 for product 1.0560672823478954 (1044/1296))
# Predicting 201904 for product 1.0587329450671956 (1045/1296))
# Predicting 201904 for product 1.0613986077864956 (1046/1296))
# Predicting 201904 for product 1.0640642705057957 (1047/1296))
# Predicting 201904 for product 1.0667299332250957 (1048/1296))
# Predicting 201904 for product 1.069395595944396 (1049/1296))
# Predicting 201904 for product 1.072061258663696 (1050/1296))
# Predicting 201904 for product 1.074726921382996 (1051/1296))
# Predicting 201904 for product 1.077392584102296 (1052/1296))
# Predicting 201904 for product 1.0800582468215962 (1053/1296))
# Predicting 201904 for product 1.0827239095408963 (1054/1296))
# Predicting 201904 for product 1.0853895722601963 (1055/1296))
# Predicting 201904 for product 1.0880552349794965 (1056/1296))
# Predicting 201904 for product 1.0907208976987965 (1057/1296))
# Predicting 201904 for product 1.0933865604180966 (1058/1296))
# Predicting 201904 for product 1.0960522231373966 (1059/1296))
# Predicting 201904 for product 1.0987178858566968 (1060/1296))
# Predicting 201904 for product 1.1013835485759969 (1061/1296))
# Predicting 201904 for product 1.1040492112952969 (1062/1296))
# Predicting 201904 for product 1.106714874014597 (1063/1296))
# Predicting 201904 for product 1.1093805367338971 (1064/1296))
# Predicting 201904 for product 1.1120461994531972 (1065/1296))
# Predicting 201904 for product 1.1147118621724972 (1066/1296))
# Predicting 201904 for product 1.1173775248917972 (1067/1296))
# Predicting 201904 for product 1.1200431876110974 (1068/1296))
# Predicting 201904 for product 1.1227088503303975 (1069/1296))
# Predicting 201904 for product 1.1253745130496975 (1070/1296))
# Predicting 201904 for product 1.1280401757689975 (1071/1296))
# Predicting 201904 for product 1.1307058384882978 (1072/1296))
# Predicting 201904 for product 1.1333715012075978 (1073/1296))
# Predicting 201904 for product 1.1360371639268978 (1074/1296))
# Predicting 201904 for product 1.1387028266461978 (1075/1296))
# Predicting 201904 for product 1.141368489365498 (1076/1296))
# Predicting 201904 for product 1.144034152084798 (1077/1296))
# Predicting 201904 for product 1.146699814804098 (1078/1296))
# Predicting 201904 for product 1.1493654775233981 (1079/1296))
# Predicting 201904 for product 1.1520311402426984 (1080/1296))
# Predicting 201904 for product 1.1546968029619984 (1081/1296))
# Predicting 201904 for product 1.1573624656812984 (1082/1296))
# Predicting 201904 for product 1.1600281284005984 (1083/1296))
# Predicting 201904 for product 1.1626937911198987 (1084/1296))
# Predicting 201904 for product 1.1653594538391987 (1085/1296))
# Predicting 201904 for product 1.1680251165584987 (1086/1296))
# Predicting 201904 for product 1.1706907792777987 (1087/1296))
# Predicting 201904 for product 1.173356441997099 (1088/1296))
# Predicting 201904 for product 1.176022104716399 (1089/1296))
# Predicting 201904 for product 1.178687767435699 (1090/1296))
# Predicting 201904 for product 1.181353430154999 (1091/1296))
# Predicting 201904 for product 1.1840190928742993 (1092/1296))
# Predicting 201904 for product 1.1866847555935993 (1093/1296))
# Predicting 201904 for product 1.1893504183128993 (1094/1296))
# Predicting 201904 for product 1.1920160810321996 (1095/1296))
# Predicting 201904 for product 1.1946817437514996 (1096/1296))
# Predicting 201904 for product 1.1973474064707996 (1097/1296))
# Predicting 201904 for product 1.2000130691900996 (1098/1296))
# Predicting 201904 for product 1.2026787319094 (1099/1296))
# Predicting 201904 for product 1.2053443946287 (1100/1296))
# Predicting 201904 for product 1.208010057348 (1101/1296))
# Predicting 201904 for product 1.2106757200673 (1102/1296))
# Predicting 201904 for product 1.2133413827866002 (1103/1296))
# Predicting 201904 for product 1.2160070455059002 (1104/1296))
# Predicting 201904 for product 1.2186727082252002 (1105/1296))
# Predicting 201904 for product 1.2213383709445003 (1106/1296))
# Predicting 201904 for product 1.2240040336638005 (1107/1296))
# Predicting 201904 for product 1.2266696963831005 (1108/1296))
# Predicting 201904 for product 1.2293353591024005 (1109/1296))
# Predicting 201904 for product 1.2320010218217006 (1110/1296))
# Predicting 201904 for product 1.2346666845410008 (1111/1296))
# Predicting 201904 for product 1.2373323472603008 (1112/1296))
# Predicting 201904 for product 1.2399980099796009 (1113/1296))
# Predicting 201904 for product 1.2426636726989009 (1114/1296))
# Predicting 201904 for product 1.2453293354182011 (1115/1296))
# Predicting 201904 for product 1.2479949981375011 (1116/1296))
# Predicting 201904 for product 1.2506606608568012 (1117/1296))
# Predicting 201904 for product 1.2533263235761012 (1118/1296))
# Predicting 201904 for product 1.2559919862954014 (1119/1296))
# Predicting 201904 for product 1.2586576490147015 (1120/1296))
# Predicting 201904 for product 1.2613233117340015 (1121/1296))
# Predicting 201904 for product 1.2639889744533015 (1122/1296))
# Predicting 201904 for product 1.2666546371726017 (1123/1296))
# Predicting 201904 for product 1.2693202998919018 (1124/1296))
# Predicting 201904 for product 1.2719859626112018 (1125/1296))
# Predicting 201904 for product 1.2746516253305018 (1126/1296))
# Predicting 201904 for product 1.277317288049802 (1127/1296))
# Predicting 201904 for product 1.279982950769102 (1128/1296))
# Predicting 201904 for product 1.282648613488402 (1129/1296))
# Predicting 201904 for product 1.2853142762077021 (1130/1296))
# Predicting 201904 for product 1.2879799389270024 (1131/1296))
# Predicting 201904 for product 1.2906456016463024 (1132/1296))
# Predicting 201904 for product 1.2933112643656024 (1133/1296))
# Predicting 201904 for product 1.2959769270849024 (1134/1296))
# Predicting 201904 for product 1.2986425898042027 (1135/1296))
# Predicting 201904 for product 1.3013082525235027 (1136/1296))
# Predicting 201904 for product 1.306639577962103 (1137/1296))
# Predicting 201904 for product 1.309305240681403 (1138/1296))
# Predicting 201904 for product 1.311970903400703 (1139/1296))
# Predicting 201904 for product 1.314636566120003 (1140/1296))
# Predicting 201904 for product 1.3173022288393033 (1141/1296))
# Predicting 201904 for product 1.3199678915586033 (1142/1296))
# Predicting 201904 for product 1.3226335542779033 (1143/1296))
# Predicting 201904 for product 1.3252992169972033 (1144/1296))
# Predicting 201904 for product 1.3279648797165036 (1145/1296))
# Predicting 201904 for product 1.3306305424358036 (1146/1296))
# Predicting 201904 for product 1.3332962051551036 (1147/1296))
# Predicting 201904 for product 1.3359618678744036 (1148/1296))
# Predicting 201904 for product 1.3386275305937039 (1149/1296))
# Predicting 201904 for product 1.341293193313004 (1150/1296))
# Predicting 201904 for product 1.343958856032304 (1151/1296))
# Predicting 201904 for product 1.346624518751604 (1152/1296))
# Predicting 201904 for product 1.3492901814709042 (1153/1296))
# Predicting 201904 for product 1.3519558441902042 (1154/1296))
# Predicting 201904 for product 1.3546215069095042 (1155/1296))
# Predicting 201904 for product 1.3572871696288042 (1156/1296))
# Predicting 201904 for product 1.3599528323481045 (1157/1296))
# Predicting 201904 for product 1.3626184950674045 (1158/1296))
# Predicting 201904 for product 1.3652841577867045 (1159/1296))
# Predicting 201904 for product 1.3679498205060046 (1160/1296))
# Predicting 201904 for product 1.3706154832253048 (1161/1296))
# Predicting 201904 for product 1.3732811459446048 (1162/1296))
# Predicting 201904 for product 1.3759468086639048 (1163/1296))
# Predicting 201904 for product 1.3786124713832049 (1164/1296))
# Predicting 201904 for product 1.381278134102505 (1165/1296))
# Predicting 201904 for product 1.3839437968218051 (1166/1296))
# Predicting 201904 for product 1.3866094595411051 (1167/1296))
# Predicting 201904 for product 1.3892751222604052 (1168/1296))
# Predicting 201904 for product 1.3919407849797054 (1169/1296))
# Predicting 201904 for product 1.3946064476990054 (1170/1296))
# Predicting 201904 for product 1.3972721104183055 (1171/1296))
# Predicting 201904 for product 1.3999377731376055 (1172/1296))
# Predicting 201904 for product 1.4026034358569057 (1173/1296))
# Predicting 201904 for product 1.4052690985762057 (1174/1296))
# Predicting 201904 for product 1.4079347612955058 (1175/1296))
# Predicting 201904 for product 1.4106004240148058 (1176/1296))
# Predicting 201904 for product 1.413266086734106 (1177/1296))
# Predicting 201904 for product 1.415931749453406 (1178/1296))
# Predicting 201904 for product 1.418597412172706 (1179/1296))
# Predicting 201904 for product 1.4212630748920063 (1180/1296))
# Predicting 201904 for product 1.4239287376113063 (1181/1296))
# Predicting 201904 for product 1.4265944003306064 (1182/1296))
# Predicting 201904 for product 1.4292600630499064 (1183/1296))
# Predicting 201904 for product 1.4319257257692066 (1184/1296))
# Predicting 201904 for product 1.4345913884885066 (1185/1296))
# Predicting 201904 for product 1.4372570512078067 (1186/1296))
# Predicting 201904 for product 1.4399227139271067 (1187/1296))
# Predicting 201904 for product 1.442588376646407 (1188/1296))
# Predicting 201904 for product 1.445254039365707 (1189/1296))
# Predicting 201904 for product 1.447919702085007 (1190/1296))
# Predicting 201904 for product 1.450585364804307 (1191/1296))
# Predicting 201904 for product 1.4532510275236072 (1192/1296))
# Predicting 201904 for product 1.4559166902429073 (1193/1296))
# Predicting 201904 for product 1.4585823529622073 (1194/1296))
# Predicting 201904 for product 1.4612480156815073 (1195/1296))
# Predicting 201904 for product 1.4639136784008075 (1196/1296))
# Predicting 201904 for product 1.4665793411201076 (1197/1296))
# Predicting 201904 for product 1.4692450038394076 (1198/1296))
# Predicting 201904 for product 1.4719106665587076 (1199/1296))
# Predicting 201904 for product 1.4745763292780079 (1200/1296))
# Predicting 201904 for product 1.4772419919973079 (1201/1296))
# Predicting 201904 for product 1.479907654716608 (1202/1296))
# Predicting 201904 for product 1.482573317435908 (1203/1296))
# Predicting 201904 for product 1.4852389801552082 (1204/1296))
# Predicting 201904 for product 1.4879046428745082 (1205/1296))
# Predicting 201904 for product 1.4905703055938082 (1206/1296))
# Predicting 201904 for product 1.4932359683131082 (1207/1296))
# Predicting 201904 for product 1.4959016310324085 (1208/1296))
# Predicting 201904 for product 1.4985672937517085 (1209/1296))
# Predicting 201904 for product 1.5012329564710085 (1210/1296))
# Predicting 201904 for product 1.5038986191903085 (1211/1296))
# Predicting 201904 for product 1.5065642819096088 (1212/1296))
# Predicting 201904 for product 1.5092299446289088 (1213/1296))
# Predicting 201904 for product 1.5118956073482088 (1214/1296))
# Predicting 201904 for product 1.5145612700675088 (1215/1296))
# Predicting 201904 for product 1.517226932786809 (1216/1296))
# Predicting 201904 for product 1.5198925955061091 (1217/1296))
# Predicting 201904 for product 1.5225582582254091 (1218/1296))
# Predicting 201904 for product 1.5252239209447092 (1219/1296))
# Predicting 201904 for product 1.5278895836640094 (1220/1296))
# Predicting 201904 for product 1.5305552463833094 (1221/1296))
# Predicting 201904 for product 1.5332209091026094 (1222/1296))
# Predicting 201904 for product 1.5358865718219097 (1223/1296))
# Predicting 201904 for product 1.5385522345412097 (1224/1296))
# Predicting 201904 for product 1.5412178972605097 (1225/1296))
# Predicting 201904 for product 1.5438835599798097 (1226/1296))
# Predicting 201904 for product 1.54654922269911 (1227/1296))
# Predicting 201904 for product 1.54921488541841 (1228/1296))
# Predicting 201904 for product 1.55188054813771 (1229/1296))
# Predicting 201904 for product 1.55454621085701 (1230/1296))
# Predicting 201904 for product 1.5572118735763103 (1231/1296))
# Predicting 201904 for product 1.5598775362956103 (1232/1296))
# Predicting 201904 for product 1.5625431990149103 (1233/1296))
# Predicting 201904 for product 1.5652088617342104 (1234/1296))
# Predicting 201904 for product 1.5678745244535106 (1235/1296))
# Predicting 201904 for product 1.5705401871728106 (1236/1296))
# Predicting 201904 for product 1.5732058498921107 (1237/1296))
# Predicting 201904 for product 1.5758715126114107 (1238/1296))
# Predicting 201904 for product 1.578537175330711 (1239/1296))
# Predicting 201904 for product 1.581202838050011 (1240/1296))
# Predicting 201904 for product 1.583868500769311 (1241/1296))
# Predicting 201904 for product 1.586534163488611 (1242/1296))
# Predicting 201904 for product 1.5891998262079112 (1243/1296))
# Predicting 201904 for product 1.5918654889272112 (1244/1296))
# Predicting 201904 for product 1.5945311516465113 (1245/1296))
# Predicting 201904 for product 1.5971968143658113 (1246/1296))
# Predicting 201904 for product 1.5998624770851115 (1247/1296))
# Predicting 201904 for product 1.6025281398044116 (1248/1296))
# Predicting 201904 for product 1.6051938025237116 (1249/1296))
# Predicting 201904 for product 1.6078594652430116 (1250/1296))
# Predicting 201904 for product 1.6105251279623118 (1251/1296))
# Predicting 201904 for product 1.6131907906816119 (1252/1296))
# Predicting 201904 for product 1.6158564534009119 (1253/1296))
# Predicting 201904 for product 1.618522116120212 (1254/1296))
# Predicting 201904 for product 1.6211877788395122 (1255/1296))
# Predicting 201904 for product 1.6238534415588122 (1256/1296))
# Predicting 201904 for product 1.6265191042781122 (1257/1296))
# Predicting 201904 for product 1.6291847669974122 (1258/1296))
# Predicting 201904 for product 1.6318504297167125 (1259/1296))
# Predicting 201904 for product 1.6345160924360125 (1260/1296))
# Predicting 201904 for product 1.6371817551553125 (1261/1296))
# Predicting 201904 for product 1.6398474178746127 (1262/1296))
# Predicting 201904 for product 1.6425130805939128 (1263/1296))
# Predicting 201904 for product 1.6451787433132128 (1264/1296))
# Predicting 201904 for product 1.6478444060325128 (1265/1296))
# Predicting 201904 for product 1.650510068751813 (1266/1296))
# Predicting 201904 for product 1.653175731471113 (1267/1296))
# Predicting 201904 for product 1.655841394190413 (1268/1296))
# Predicting 201904 for product 1.6585070569097131 (1269/1296))
# Predicting 201904 for product 1.6611727196290134 (1270/1296))
# Predicting 201904 for product 1.6638383823483134 (1271/1296))
# Predicting 201904 for product 1.6665040450676134 (1272/1296))
# Predicting 201904 for product 1.6691697077869134 (1273/1296))
# Predicting 201904 for product 1.6718353705062137 (1274/1296))
# Predicting 201904 for product 1.6745010332255137 (1275/1296))
# Predicting 201904 for product 1.6771666959448137 (1276/1296))
# Predicting 201904 for product 1.6798323586641137 (1277/1296))
# Predicting 201904 for product 1.682498021383414 (1278/1296))
# Predicting 201904 for product 1.685163684102714 (1279/1296))
# Predicting 201904 for product 1.687829346822014 (1280/1296))
# Predicting 201904 for product 1.690495009541314 (1281/1296))
# Predicting 201904 for product 1.6931606722606143 (1282/1296))
# Predicting 201904 for product 1.6958263349799143 (1283/1296))
# Predicting 201904 for product 1.6984919976992143 (1284/1296))
# Predicting 201904 for product 1.7011576604185144 (1285/1296))
# Predicting 201904 for product 1.7038233231378146 (1286/1296))
# Predicting 201904 for product 1.7064889858571146 (1287/1296))
# Predicting 201904 for product 1.7091546485764146 (1288/1296))
# Predicting 201904 for product 1.7118203112957147 (1289/1296))
# Predicting 201904 for product 1.714485974015015 (1290/1296))
# Predicting 201904 for product 1.717151636734315 (1291/1296))
# Predicting 201904 for product 1.719817299453615 (1292/1296))
# Predicting 201904 for product 1.722482962172915 (1293/1296))
# Predicting 201904 for product 1.7251486248922152 (1294/1296))
# Predicting 201904 for product 1.7278142876115152 (1295/1296))
# Predicting 201904 for product 1.7304799503308153 (1296/1296))

# %%
from datetime import datetime
# Display a sample of the final output
final_output = pd.DataFrame(rows,
    columns=["product_id", "predicted_tn_for_201904", "actual_tn_for_201904"]
)
final_output = final_output.sort_values("product_id", ascending=True)
timestamp = datetime.now().timestamp()
final_output.to_csv(f"./output/output_lstm7_por_producto_{timestamp}.csv", index=False)
final_output.head()
# Out:
#    product_id  predicted_tn_for_201904  actual_tn_for_201904
# 0   -1.729550                17.129068                     0
# 1   -1.726885                17.583498                     0
# 2   -1.724219                 6.459624                     0
# 3   -1.721553                 5.997224                     0
# 4   -1.718888                 4.174294                     0

# %%
final_output.rename(columns={"predicted_tn_for_201904": "target"}, inplace=True)

# %%
# revert the standarization for the output
final_output["target"] = scaler_predict_target.inverse_transform(final_output[["target"]])
final_output["product_id"] = scaler_predict_product_id.inverse_transform(final_output[["product_id"]])
final_output
# Out:
#       product_id       target  actual_tn_for_201904
# 0        20001.0  1653.988403                     0
# 1        20002.0  1697.082886                     0
# 2        20003.0   642.183716                     0
# 3        20004.0   598.333374                     0
# 4        20005.0   425.461182                     0
# ...          ...          ...                   ...
# 1291     21295.0    29.604591                     0
# 1292     21296.0    29.604591                     0
# 1293     21297.0    29.604591                     0
# 1294     21298.0    29.604591                     0
# 1295     21299.0    29.604591                     0
#
# [1296 rows x 3 columns]

# %%
# set pandas max rows to display options to 200
pd.set_option('display.max_rows', 100)
final_output.head(100)
# Out:
#     product_id       target  actual_tn_for_201904
# 0      20001.0  1653.988403                     0
# 1      20002.0  1697.082886                     0
# 2      20003.0   642.183716                     0
# 3      20004.0   598.333374                     0
# 4      20005.0   425.461182                     0
# 5      20006.0   673.051575                     0
# 6      20007.0   336.170166                     0
# 7      20008.0   546.651611                     0
# 8      20009.0   222.347000                     0
# 9      20010.0   411.713501                     0
# 10     20011.0   423.437408                     0
# 11     20012.0   279.080017                     0
# 12     20013.0   434.463654                     0
# 13     20014.0   338.893890                     0
# 14     20015.0   263.216766                     0
# 15     20016.0   311.022095                     0
# 16     20017.0   240.297852                     0
# 17     20018.0   293.135498                     0
# 18     20019.0   298.837097                     0
# 19     20020.0   288.431030                     0
# 20     20021.0   291.685059                     0
# 21     20022.0   370.858978                     0
# 22     20023.0   222.832520                     0
# 23     20024.0   407.745819                     0
# 24     20025.0   296.237640                     0
# 25     20026.0   212.325516                     0
# 26     20027.0   248.481033                     0
# 27     20028.0   219.271500                     0
# 28     20029.0   190.862625                     0
# 29     20030.0    29.604591                     0
# 30     20031.0   150.459656                     0
# 31     20032.0    29.604591                     0
# 32     20033.0   132.590988                     0
# 33     20034.0   258.589203                     0
# 34     20035.0   229.726318                     0
# 35     20036.0    29.604591                     0
# 36     20037.0   150.333282                     0
# 37     20038.0   152.039291                     0
# 38     20039.0    29.604591                     0
# 39     20040.0   161.019470                     0
# 40     20041.0   198.587982                     0
# 41     20042.0   138.671021                     0
# 42     20043.0    29.604591                     0
# 43     20044.0    29.604591                     0
# 44     20045.0   152.522385                     0
# 45     20046.0   146.260803                     0
# 46     20047.0    29.604591                     0
# 47     20048.0   170.970047                     0
# 48     20049.0   164.684982                     0
# 49     20050.0   159.441422                     0
# 50     20051.0    29.604591                     0
# 51     20052.0    29.604591                     0
# 52     20053.0    29.604591                     0
# 53     20054.0    29.604591                     0
# 54     20055.0    29.604591                     0
# 55     20056.0    29.604591                     0
# 56     20057.0    29.604591                     0
# 57     20058.0    29.604591                     0
# 58     20059.0    29.604591                     0
# 59     20060.0    29.604591                     0
# 60     20061.0    29.604591                     0
# 61     20062.0    29.604591                     0
# 62     20063.0    29.604591                     0
# 63     20064.0   136.091965                     0
# 64     20065.0    29.604591                     0
# 65     20066.0    29.604591                     0
# 66     20067.0   149.817581                     0
# 67     20068.0    29.604591                     0
# 68     20069.0   145.155807                     0
# 69     20070.0    29.604591                     0
# 70     20071.0    29.604591                     0
# 71     20072.0    29.604591                     0
# 72     20073.0    29.604591                     0
# 73     20074.0    29.604591                     0
# 74     20075.0   176.732040                     0
# 75     20076.0    29.604591                     0
# 76     20077.0    29.604591                     0
# 77     20078.0    29.604591                     0
# 78     20079.0    29.604591                     0
# 79     20080.0    29.604591                     0
# 80     20081.0    29.604591                     0
# 81     20082.0    29.604591                     0
# 82     20083.0    29.604591                     0
# 83     20084.0    29.604591                     0
# 84     20085.0   162.264725                     0
# 85     20086.0    29.604591                     0
# 86     20087.0    29.604591                     0
# 87     20088.0    29.604591                     0
# 88     20089.0   271.859070                     0
# 89     20090.0    29.604591                     0
# 90     20091.0    29.604591                     0
# 91     20092.0    29.604591                     0
# 92     20093.0    29.604591                     0
# 93     20094.0   155.319016                     0
# 94     20095.0    29.604591                     0
# 95     20096.0    29.604591                     0
# 96     20097.0    29.604591                     0
# 97     20098.0    29.604591                     0
# 98     20099.0    29.604591                     0
# 99     20100.0    29.604591                     0

# %%
from empresa4.core import calculate_error_2

# %%
final_output["product_id"] = final_output["product_id"].astype(int)

# %%
final_output.rename(columns={"target": "prediction"}, inplace=True)

# %%
calculate_error_2(final_output[final_output["product_id"] == 20005], 201904)
# Out:
# 0.3192608023557405

# %%
calculate_error(final_output["predicted_tn_for_201904"].to_list(), final_output["actual_tn_for_201904"].to_list())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/gero/Documents/Austral/Laboratorio de Implementación 3/consultoria-multinacional/LSTM/lstm7_productos.ipynb Cell 43 line 1
# ----> <a href='vscode-notebook-cell:/home/gero/Documents/Austral/Laboratorio%20de%20Implementaci%C3%B3n%203/consultoria-multinacional/LSTM/lstm7_productos.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> calculate_error(final_output["predicted_tn_for_201904"].to_list(), final_output["actual_tn_for_201904"].to_list())
#
# NameError: name 'calculate_error' is not defined

# %%
from empresa4.core import filter_productos_importantes
final_output_productos_importantes = filter_productos_importantes(final_output)
calculate_error(final_output_productos_importantes["predicted_tn_for_201904"].to_list(), final_output_productos_importantes["actual_tn_for_201904"].to_list())
# Out:
# 0.41021309162226854

# %%
calculate_error(
    final_output[final_output["product_id"] == 20001][
        "predicted_tn_for_201904"
    ].to_list(),
    final_output[final_output["product_id"] == 20001]["actual_tn_for_201904"].to_list(),
)
# Out:
# 0.4201643323446362
